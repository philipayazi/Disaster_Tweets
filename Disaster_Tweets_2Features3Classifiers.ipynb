# %% [markdown]
# ## Load Imports

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

from gensim.parsing.preprocessing import preprocess_string
from gensim.parsing.preprocessing import strip_punctuation,strip_multiple_whitespaces,remove_stopwords
from gensim.corpora import Dictionary

import xgboost as xgb

# %% [markdown]
# ## Load Tweet Dataset and Clean it

# %%
# read data into pandas data frame
initial_df = pd.read_csv("nlp-getting-started/train.csv")
df = pd.read_csv("nlp-getting-started/train.csv")

initial_df.head()
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
# clean tweets of white spaces, punctuations, stopwords, and make all letters lowercase
custom_filters = [lambda x: x.lower(),
                  strip_multiple_whitespaces,
                  strip_punctuation,
                  remove_stopwords]

def clean_string(row):
    return preprocess_string(row['text'], custom_filters)

# %%
# append cleaned tweets to dataframe
initial_df['cleaned_tweets'] = initial_df.apply(clean_string, axis=1)

initial_df.head()
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target                                     cleaned_tweets
# 0       1        [deeds, reason, earthquake, allah, forgive]
# 1       1            [forest, near, la, ronge, sask, canada]
# 2       1  [residents, asked, shelter, place, notified, o...
# 3       1  [13, 000, people, receive, wildfires, evacuati...
# 4       1  [got, sent, photo, ruby, alaska, smoke, wildfi...

# %%
cleaned_tweets_lst = initial_df['cleaned_tweets'].to_list()
cleaned_tweets_lst = [' '.join(cleaned_tweet) for cleaned_tweet in cleaned_tweets_lst]
cleaned_tweets_lst
# Out:
# ['deeds reason earthquake allah forgive',
#  'forest near la ronge sask canada',
#  'residents asked shelter place notified officers evacuation shelter place orders expected',
#  '13 000 people receive wildfires evacuation orders california',
#  'got sent photo ruby alaska smoke wildfires pours school',
#  'rockyfire update california hwy 20 closed directions lake county cafire wildfires',
#  'flood disaster heavy rain causes flash flooding streets manitou colorado springs areas',
#  'm hill woods',
#  's emergency evacuation happening building street',
#  'm afraid tornado coming area',
#  'people died heat wave far',
#  'haha south tampa getting flooded hah wait second live south tampa gonna gonna fvck flooding',
#  'raining flooding florida tampabay tampa 18 19 days ve lost count',
#  'flood bago myanmar arrived bago',
#  'damage school bus 80 multi car crash breaking',
#  's man',
#  'love fruits',
#  'summer lovely',
#  'car fast',
#  'goooooooaaaaaal',
#  'ridiculous',
#  'london cool',
#  'love skiing',
#  'wonderful day',
#  'looooool',
#  'way t eat shit',
#  'nyc week',
#  'love girlfriend',
#  'cooool',
#  'like pasta',
#  'end',
#  'bbcmtd wholesale markets ablaze http t lhyxeohy6c',
#  'try bring heavy metal rt http t yao1e0xngw',
#  'africanbaze breaking news nigeria flag set ablaze aba http t 2nndbgwyei',
#  'crying set ablaze',
#  'plus look sky night ablaze http t qqsmshaj3n',
#  'phdsquares mufc ve built hype new acquisitions doubt set epl ablaze season',
#  'inec office abia set ablaze http t 3imaomknna',
#  'barbados bridgetown jamaica \x89ûò cars set ablaze santa cruz \x89ûó head st elizabeth police superintende http t wdueaj8q4j',
#  'ablaze lord d',
#  'check http t roi2nsmejj http t 3tj8zjin21 http t yduixefipe http t lxtjc87kls nsfw',
#  'outside ablaze alive dead inside',
#  'awesome time visiting cfc head office ancop site ablaze thanks tita vida taking care',
#  'soooo pumped ablaze southridgelife',
#  'wanted set chicago ablaze preaching hotel http t o9qknbfofx',
#  'gained 3 followers week know stats grow http t tiyulif5c6',
#  'west burned thousands wildfires ablaze california http t vl5tbr3wbr',
#  'building perfect tracklist life leave streets ablaze',
#  'check http t roi2nsmejj http t 3tj8zjin21 http t yduixefipe http t lxtjc87kls nsfw',
#  'night retainers s weird better wear single night year',
#  'deputies man shot brighton home set ablaze http t gwnrhmso8k',
#  'man wife years jail setting ablaze niece http t ev1ahoucza',
#  'santa cruz \x89ûó head st elizabeth police superintendent lanford salmon r http t vplr5hka2u http t sxhw2tnnlf',
#  'police arsonist deliberately set black church north carolinaåêablaze http t pcxarbh9an',
#  'noches el bestia alexis sanchez happy teammates training hard goodnight gunners http t uc4j4jhvgr',
#  'kurds trampling turkmen flag later set ablaze vandalized offices turkmen diyala http t 4izfdyc3cg',
#  'truck ablaze r21 voortrekker ave outside tambo intl cargo section http t 8kscqkfkkf',
#  'set hearts ablaze city gift skyline like kiss lips \x89û https t cyompz1a0z',
#  'sky ablaze tonight los angeles m expecting ig fb filled sunset shots know peeps',
#  'west burned thousands wildfires ablaze california http t icsjgz9te1 climate energy http t 9fxmn0l0bd',
#  'revel wmv videos means mac farewell ablaze wmv en route dvd gtxrwm',
#  'progressive greetings month students set pens ablaze torch publications http t 9fxpixqujt',
#  'rene ablaze amp jacinta secret 2k13 fallen skies edit mar 30 2013 https t 7mlmsuzv1z',
#  'navista7 steve fires california tinderbox clown setting hood ablaze news24680',
#  'nowplaying rene ablaze amp ian buff magnitude http t av2jsjfftc edm',
#  'nxwestmidlands huge wholesale markets ablaze http t rwzbfvnxer',
#  'ablaze time talk t know work',
#  't kids cuz got bicycle accident amp split testicles s impossible kids michael father',
#  'accident 24 w nashvilletraffic traffic moving 8m slower usual https t 0ghk693egj',
#  'accident center lane blocked santaclara 101 nb great america pkwy bayarea traffic http t pmlohzurwr',
#  'http t gkye6gjtk5 personalinjury accident summer read advice amp solicitor help otleyhour',
#  'stlouis caraccidentlawyer speeding causes teen accidents https t k4zomof319 https t s2kxvm0cba car accident tee\x89û',
#  'reported motor vehicle accident curry herman rd near stephenson involving overturned vehicle use http t ybjezkurw1',
#  'bigrigradio live accident awareness',
#  '77 mile marker 31 south mooresville iredell vehicle accident ramp closed 8 6 1 18 pm',
#  'rt sleepjunkies sleeping pills double risk car accident http t 7s9nm1fict',
#  'accident knew gon happen https t ysxun5vceh',
#  'traffic accident n cabrillo hwy magellan av mir 08 06 15 11 03 58',
#  '77 mile marker 31 40 south mooresville iredell vehicle accident congestion 8 6 1 18 pm',
#  'pastor scene accident owner range rover',
#  'mom t home fast wished mom accident truck spilt mayonnaise',
#  'horrible car accident past sunday m finally able thank god',
#  'wait pissed donnie tell accident',
#  'truckcrash overturns fortworth interstate http t rs22lj4qfp click ve crash gt http t ld0uniyw4k',
#  'accident ashville 23 sb sr 752 traffic http t hylmo0wgfi',
#  'carolina accident motorcyclist dies 540 crash car crossed median motorcycle rider traveling http t p18lzrlmy6',
#  'fyi cad fyi accident property damage nhs 999 piner rd horndale dr',
#  'rt naayf accident years turning chandanee magu near mma taxi rammed halfway turned conf\x89û',
#  'accident left lane blocked manchester rt 293 nb eddy rd stop traffic nh 3a delay 4 mins traffic',
#  'accident property damage piner rd horndale dr',
#  'accident http t oia5fxi4gm',
#  'fyi cad fyi accident property damage wpd 1600 s 17th st',
#  '8 6 2015 2 09 pm traffic accident injury 2781 willis foreman rd http t vckit6edev',
#  'aashiqui actress anu aggarwal near fatal accident http t 6otfp31lqw',
#  'suffield alberta accident https t bptmlf4p10',
#  '9 mile backup 77 south accident blocking right 2 lanes exit 31 langtree rd consider nc 115 nc 150 nc 16 alternate',
#  'accident changed life help determine options financially support life care plans going treatment',
#  'breaking deadly motorcycle car accident happened hagerstown today ll details 5 your4state whag',
#  'flowri marinading accident',
#  'car week got fucking car accident mfs t fucking drive',
#  'norwaymfa bahrain police previously died road accident killed explosion https t gfjfgtodad',
#  'heard church leaders kenya coming forward comment accident issue disciplinary measures arrestpastornganga',
#  'aftershock delo scuf ps live game cya',
#  'man drive effort gets painful man win roger bannister',
#  '320 ir icemoon aftershock http t ynxnvvkcda djicemoon dubstep trapmusic dnb edm dance ices\x89û http t weqpesenku',
#  'victory bargain basement prices dwight david eisenhower',
#  '320 ir icemoon aftershock http t vam5podgyw djicemoon dubstep trapmusic dnb edm dance ices\x89û http t zevakjapcz',
#  'remembers came second charles schulz',
#  'aftershock delo im speaking scuf xb1 people end getting ps',
#  'harder conflict glorious triumph thomas paine',
#  'growingupspoiled going clay pigeon shooting crying aftershock',
#  'guess actually wants free aftershock tc',
#  'aftershock terrifying best roller coaster ve disclaimer ve',
#  'aftershock https t xmwodfmtui',
#  '320 ir icemoon aftershock http t m4jdzmgjow djicemoon dubstep trapmusic dnb edm dance ices\x89û http t n0uhasfkbv',
#  '320 ir icemoon aftershock http t vam5podgyw djicemoon dubstep trapmusic dnb edm dance ices\x89û http t zevakjapcz',
#  '320 ir icemoon aftershock http t e14epzhoth djicemoon dubstep trapmusic dnb edm dance ices\x89û http t 22a9d5do6q',
#  'kjfordays m seeing issues aftershock',
#  '320 ir icemoon aftershock http t thyzomvwu0 djicemoon dubstep trapmusic dnb edm dance ices\x89û http t 83joo0xk29',
#  '320 ir icemoon aftershock http t thyzomvwu0 djicemoon dubstep trapmusic dnb edm dance ices\x89û http t 83joo0xk29',
#  'wisdomwed bonus 5 minute daily habits improve life lifehacks http t tbm9fqb8cw',
#  'aftershock protect profit global financial meltdown david wiedemer http http t wztz4hgmvq',
#  'moment scary roller coaster guy screaming bloody murder silverwood aftershock',
#  'aftershock \x89ã¢ 2010 full\x89ã¢ streaming youtube http t vve3usesgf',
#  'gt gt 15 aftershock protect profit global financial book http t f6ntuc734z esquireattire',
#  'face difficulties wrong right joel osteen',
#  'thing stands dream try belief actually possible joel brown',
#  'praise god ministry tells like wdyouth biblestudy https t ujk0e5gbcc',
#  'remembering going die best way know avoid trap thinking lose \x89ûò steve jobs',
#  'tried orange aftershock today life',
#  'onfireanders love bb',
#  'aftershock https t jv8ppkhjy7',
#  'aftershock school kick great want thank making possible great night',
#  'people interrupt \x89ûò george bernard shaw',
#  'man gets oyster second man gets shell andrew carnegie',
#  'need p u tonight play hybrid slayer ps4 eu hmu cod8sandscrims empirikgaming codawscrims 4tp kotc 4tpfa aftershock org',
#  'experts france begin examining airplane debris reunion island french air accident experts o http t yvvpznzmxg news',
#  'strict liability context airplane accident pilot error common component aviation cr http t 6cz3bohrd4',
#  'crobscarla lifetime odds dying airplane accident 1 8015',
#  'experts france begin examining airplane debris reunion island french air accident experts wedn http t bkpfpogysi',
#  'alexalltimelow awwww airplane accident gonna die cuties good job',
#  'family members osama bin laden died airplane accident ironic mhmmm gov shit suspect',
#  'man goes airplane engine accident http t tyjxrfd3st youtube',
#  'horrible accident man died wings airplane 29 07 2015 http t i7kztevb2v',
#  'cessna airplane accident ocampo coahuila mexico july 29 2015 killed men including state coahuila government official',
#  'horrible accident man died wings airplane 29 07 2015 watchthevideo http t p64xrvgjik',
#  'experts france begin examining airplane debris reunion island http t lsmx2vwr3j french air accident experts wednesday\x89û',
#  'experts france begin examining airplane debris reunion island french air accident experts wednesday began examining t',
#  'kca votejkt48id mbataweel rip binladen family members killed airplane s accident',
#  'sent coworker nudes accident thank god airplane mode',
#  'mickinyman theatlantic killed airplane accident night car wreck politics s best',
#  'experts france begin examining airplane debris reunion island french air accident experts http t tagzbcxfj0 mlb',
#  'unbelievably insane man airport airplane aircraft aeroplane runway accident freaky\x89û https t cezhq7czll',
#  'horrible accident man died wings airplaneåê 29 07 2015 http t wq3wjsgphl',
#  'horrible accident man died wings airplane 29 07 2015 http t tfcdronra6',
#  'usama bin ladins family dead airplane crash naturally accident',
#  'pilot dies plane crash car festival https t kq9ae6ap2b youtube crash aircraft airplane pilot death accident carfest',
#  'strict liability context airplane accident http t gibyqhhkpk',
#  'dtn brazil experts france begin examining airplane debris reunion island french air accident exp http t m9ig3wq8lq',
#  'experts france begin examining airplane debris reunion island french air accident experts wedn http t v4smaeslk5',
#  'horrible accident man died wings \x89ûïairplane\x89û\x9d 29 07 2015 wtf can\x89ûªt believe eyes \x89ûò http t 6ffylajwps',
#  'nicole fletcher victim crashed airplane times ago accident left little bit trauma s',
#  'omg horrible accident man died wings airplane http t xdxdprcpns',
#  'omg t believe rip bro airplane accident jetengine turbojet boing g90 http t kxxnszp6nk',
#  'experts france begin examining airplane debris reunion island french air accident experts wednesday began examining t',
#  'airplane accident',
#  'phone looks like car ship airplane accident terrible',
#  'statistically m risk getting killed cop dying airplane accident',
#  'airplane crashes house colombia 12 people die accident https t zhjlflbhzl',
#  'shooting airplane accident https t iecc1jdoub',
#  'drone cause airplane accident pilots worried use drones esp close vicinity airports http t kz35rgngjf',
#  'early wake sister begging come amp ride w ambulance hospital rodkiai',
#  'http t ay6zzcupnz feared killed pakistani air ambulance helicopter crash http t sc9dns41mc',
#  'air ambulances scene crash cars lorry http t 9pfeaqeski http t fntg70rnkx emsne\x89û',
#  'feared killed pakistani air ambulance helicopter crash reuters http t mdnugvubwn yugvani',
#  'leading emergency services boss welcomes new ambulance charity http t mj2jq2psv6',
#  'travelling aberystwyth shrewsbury right s incident services halt outside shrews ambulance scene',
#  'feared killed pakistani air ambulance helicopter crash http t xum8ylcb4q',
#  'ambulance sprinter automatic frontline vehicle choice 14 lez compliant ebay http t 4evttqpeia',
#  'new nanotech device able target destroy blood clots http t hfy5v3slbb',
#  '20skyhawkmm20 traplord 29 fredosantana300 lilreese300 hella crazy 3 fights ambulance couple mosh pits',
#  'run ambulance lucky justsaying randomthought',
#  'news feared killed pakistani air ambulance helicopter crash http t bfes5twbzt til dna',
#  'http t 7xglah10zl feared killed pakistani air ambulance helicopter crash http t thmblaatzp',
#  'tanslash waiting ambulance',
#  'fouseytube ok need ambulance hahahah good http t zsberqnn9n',
#  'ambulance sprinter automatic frontline vehicle choice 14 lez compliant ebay http t q8ivrzojzv',
#  'pakistan air ambulance helicopter crash kills http t 8e7ry8ebmf',
#  'thenissonian rejectdcartoons nissan ok need medical assistance ambulance need',
#  'ems1 ny emts petition 17 hour \x89û÷minimum wage\x89ûª http t 4oa6swlxmr ems paramedics ambulance',
#  'http t fcqmkffflw feared killed pakistani air ambulance helicopter crash http t vayaymbngu',
#  'feared killed pakistani air ambulance helicopter crash http t 3brme6sn4t',
#  'ambulance sprinter automatic frontline vehicle choice 14 lez compliant ebay http t ujrx9kgawp',
#  'ambulance sprinter automatic frontline vehicle choice 14 lez compliant ebay http t kp2lf4aute',
#  'kiwi karyn check s parking lot said year ambulance st johns http t hpvodud7ip',
#  't know way ambulance coming lt lt',
#  'reuters feared killed pakistani air ambulance helicopter crash http t shzpyiqok5',
#  'http t pwwpum6rbj feared killed pakistani air ambulance helicopter crash http t yspon4d6qo',
#  'ambulance right outside work',
#  '\x89ûï leoblakecarter dog thinks s ambulance http t mg1lpgr0rm\x89û\x9d natasha rideout',
#  'happening hatzolah ems ambulance responding dual sirens and\x89û https t sek6mq6njf',
#  'http t fuerk0gwui feared killed pakistani air ambulance helicopter crash http t mv7ggglmvc',
#  'http t x5yeuylt1x feared killed pakistani air ambulance helicopter crash http t 2ugrmd1z1n',
#  'feared killed pakistani air ambulance helicopter crash http t th9ywbbeet worldnews',
#  'feared killed pakistani air ambulance helicopter crash http t x2qsjod40u worldnews',
#  's police ambulance number lesotho body know',
#  'medic914 aace org surprised standardised clinical practice 11 nhs ambulance trust',
#  'http t j8tyt1xrrk feared killed pakistani air ambulance helicopter crash http t 9d4nazoi94',
#  'people try j walk ambulance passing hate',
#  'episode trunks annihilated freiza cleanest shit showed nigga mercy',
#  'shall annihilated petebests dessicated laid bare shall kneel',
#  'uribe annihilated baseball mets',
#  'marksmaponyane hey sundowns annihilated previous meeting celtic improvement',
#  'volfan326 tneazzy mizzou annihilated florida past 2 seasons ended muschamp s career t compete bama',
#  'annihilated abs http t 1xpw292tje',
#  'annihilated status education mba behalf easy street careen eovm http t e0pi0c54ff',
#  'luka die annihilated alois trancy',
#  'acarewornheart good fella sorry won t annihilated',
#  'cop pulls drunk driver safety seconds car hit train http t thrhkhogcuåê http t tzszmf2qxe viralspell',
#  'annihilated',
#  'cop pulls drunk driver safety seconds car hit train http t c0nkgp6w03åê http t imwmfdjssn viralspell',
#  'boom country entirely annihilated h\x89û \x89ûó britain https t irfcn71szv',
#  'amirkingkhan annihilated thank floydmayweather',
#  'thing sure god promised israel annihilated horror iran w nukes https t xn09mx6sxy',
#  'violentfeminazi guess s ok armenians ve spent history getting annihilated',
#  '70 years annihilated 100000 people instantly aware ability annihilate humanity',
#  'day 1 tryouts went good minus fact stopped quickly short ball annihilated toenail injury',
#  '1960s oryx symbol arabian peninsula annihilated hunters http t yangeqbuqw http t jq2eh5kglt',
#  'luka die annihilated alois trancy',
#  'ready annihilated bucs game',
#  'philipduncan breakfastone people annihilated nights weather philip thought forecast',
#  'domain sophistication annihilated closely minute feat zrnf',
#  'stormbeard steel lord seen judas priest 2005 rob came scorpions support fucking annihilated place astonishing gig',
#  'officially skipping fantasticfour fant4stic hashtag s getting annihilated reviews bummer',
#  'tomcatarts explaining annihilated case survivor evolved godlike',
#  'completely annihilated cech paul keegan time alive',
#  'tomcatarts annihilated legion survivors imperfect hybrid project quickly formed new secret cell',
#  'sirbrandonknt exactly s lesnar cena match summerslam year great brock annihilated guy s',
#  'cop pulls drunk driver safety seconds car hit train http t f1bakpnyn6åê http t lzxwoaye4x viralspell',
#  'annihilated damascus syrian army grinds \x89û÷alloosh gang manure pile http t 7rakhp3bwm',
#  'thatdes ok wasn t completely forthright food coma bc kebab tahini pickles annihilated w fries',
#  'fun filled happy hour simmons bar camden handsome got annihilated apart game http t 4jno677zkv',
#  'juanny beisbol sr annihilated ball lgm',
#  'rvfriedmann hell fraction belief total annihilation destruction usa lodisilverado ritzy jewels',
#  'potus maybe israel tell sorry pres sold river annihilation',
#  'evildead annihilation civilization http t spfke5kqu4',
#  'u s national park services tonto national forest stop annihilation salt river wild horse http t 6lojoorouk change',
#  'annihilating quarterstaff annihilation',
#  'world annihilation vs self transformation http t pyehwodwun aliens attack exterminate humans http t pb2n77nskz',
#  'starmade stardate 3 planetary annihilation http t i2hhviumtm youtube',
#  'u s national park services tonto national forest stop annihilation salt river wild horse https t m8mvdspjp7 change',
#  'u s national park services tonto national forest stop annihilation salt river wild horse https t sw1sbua3mn change',
#  'kimkardashian sign share petition save wild horses arizona http t 3tssxphufe',
#  'u s national park services tonto national forest stop annihilation salt river wild horse http t kpqk0c4g0m change',
#  'theellenshow check salt river horses help stop annihilation happen 54000 signatures change org thx',
#  'souls punished withåêannihilation http t c1qxjweqqu http t zhp0sowxry',
#  'calfreedommom steph93065 mention major contributor annihilation israel',
#  'willienelson need help horses die rt amp sign petition stand amp voice gilbert23 https t e8dl1lncvu',
#  'reject laws misguided false prophets imprison nations fueling self annihilation',
#  'u s national park services tonto national forest stop annihilation salt river wild horse https t matijwkzbh change',
#  'annihilation jeb christie amp kasich 24 hours away god allow day',
#  'barbi twins need help horses die rt amp sign petition stand amp voice gilbert23 https t e8dl1lncvu',
#  'whippenz need help horses die rt amp sign petition stand amp voice gilbert23 https t e8dl1lncvu',
#  'hey az sign petition save wildhorses tantonationalforest rollingstones sing long order http t wm5l8pj2iy',
#  'stop annihilation salt river wild horses http t wvobvvtxkg change',
#  'sonofbaldwin s current nova bookslast checked tied books 2011 rider died annihilation',
#  'u s national park services tonto national forest stop annihilation salt river wild horse https t x2wn7o2a3w change',
#  'sign amp rt save saltriverwildhorses http t ikuayuseqt http t bqbhuyfme9',
#  'thanks count dante join following annihilation zone johnny',
#  'world annihilation vs self transformation http t pyehwodwun aliens attack exterminate humans http t 8jxql8cv8z',
#  'u s national park services tonto national forest stop annihilation salt river wild horse https t 0fekgyby5f change',
#  'u s national park services tonto national forest stop annihilation salt river wild horse http t sb5r7shccj change',
#  'm gonna fight taylor soon',
#  'ohh fukurodani t survive apocalypse bokuto feels horrible poor boy ppor child',
#  'jocelyn birthday apocalypse',
#  'rt janenelson097 rt stephenscifi adaptation watch charlie human s apocalypse optioned film sciencefiction \x89û',
#  'apocalypse',
#  'hour s august 05 2015 08 02pm s red rover zombie apocalypse 2014 http t cf9e6tu3g7 internetradio collegeradi\x89û',
#  'honeybunzgem primalkitchen feel like pull stages apocalypse',
#  's kinda hot played radio today s disease apocalypse started careful',
#  's apocalypse lol gf m8',
#  'know s question interpretation sign apocalypse called https t my8q1uwijn',
#  'julie r apocalypse version romeo juliet warmbodies',
#  'apocalypse',
#  'rt fittscott minecraft night lucky block mod bob apocalypse wither 2 0 amp mod showcase popularmmos http t mul1j9aeux vi\x89û',
#  'begins day snow apocalypse',
#  'rt mother mary short reading apocalypse 21 1023 spirit angel took enormous high mountain \x89û',
#  'candylit imagine sarumi zombie apocalypse fighting heart heart conversations http t xizkjfff29',
#  'rt zonewolf123 liked youtube video http t u66kyg11zd minecraft night lucky block mod bob apocalypse wither 2 0 amp mo\x89û',
#  's planet s lone audience apocalypse',
#  'dad bought dvd looks like science doc read s actually impending biblical apocalypse',
#  'alexandrapullin apocalypse comes week know ll',
#  'look grizzly peak right looks like beginning dystopian apocalypse movie',
#  'niece asked scared apocalypse',
#  's storm cairo latest x men apocalypse set photo https t fs012trudg yahootv',
#  'minecraft night lucky block mod bob apocalypse wither 2 0 amp mod showcase popularmmos http t tngye2fklv youtube',
#  'shot heart xv going totally love bad heart pierc http t xpfmr368uf http t ejdhvlkxaf',
#  'rt geek apocalypse 4pm gmt hesse plays dark souls 2 day 9 http t tngpshnl87 http t imzlnzltf5 etcpb',
#  'know zombies http t huthxlkyxy',
#  'latest bryansinger reveals storm queen apocalypse rupaul alexshipppp http t oqw8jx6rts',
#  'shadow boxing apocalypse',
#  'short reading apocalypse 21 1023 spirit angel took enormous high mountain http t v8aftd9zez',
#  'enjoyed live action attack titan time posters m reminded freshly clean coiffed apocalypse',
#  'liked youtube video http t ki1ykrs9fi minecraft night lucky block mod bob apocalypse wither 2 0 amp mod showcase',
#  'pbban temporary 300 avysss armageddon kill flags fast xp reason',
#  'pbban temporary 300 russaky89 armageddon kill flags fast xp reason',
#  'official vid doublecups gt gt https t lfkmtzaekk gt gt trubgme prod thisizbwright gt gt armageddon',
#  'ouvindo peace love amp armageddon',
#  'best movie ve seen armageddon http t qouxigdtbz',
#  'bed time t wake revolution armageddon start',
#  'red faction armageddon microsoft xbox 360 2011 read ebay http t ypbvs1ijya http t 9dflv6ynqr',
#  'katiekatcubs know shit goes world series armageddon',
#  'rt ophiuchus2613 love truelove romance lith voodoo seduction astrology rtrrt lotz 9 11 apocalypse armageddon 1008pla\x89û',
#  'im gonna beat armageddon hsu hao got flawless try',
#  'enews ben affleck know s wife kids girls t help ve loved armageddon eonlinechat',
#  'd long coat hand d worn certainty armageddon bears sense occasion',
#  'phone spying hidden door nsa data mining software financial armageddon blog http t qycw5jjaj1',
#  'pbban temporary 300 hyider ghost2 armageddon kill flags fast xp reason',
#  'rt rtrrtcoach love truelove romance lith voodoo seduction astrology rtrrt lotz 9 11 apocalypse armageddon 1008planet\x89û',
#  'pbban temporary 300 fighterdena armageddon kill flags fast xp reason',
#  'photo sketch based taste armageddon episode startrek tos http t a2e6dcsk88',
#  'armageddon https t ucsudk3q1d',
#  'aberdeenfc aberdeenfanpage good luck tomorrow night coefficient points plz armageddon',
#  'paddytomlinson1 armageddon',
#  'rohnertparkdps history books thank justice department way haven t paid income tax 20yrs',
#  'vladimir putin issues major warning late escape armageddon http t gbxafy1m1c',
#  'god s kingdom heavenly gov t rule people earth armageddon http t 8hgcbxukz0 http t 4kopkcyvtt',
#  'l b entertainment lot 8 brucewillis movies dvd die hard 1 2 12 monkeys armageddon sixth ebay auction http t cxdjapzxmp',
#  'let\x89ûªs talk goof guild saunders come right stage https t hkbxxvd9iw',
#  'karnythia niece gaining ability stand m getting prepared toddler apocalypse armageddon',
#  'check preppers doomsday library collection cd shtf preppertalk survival 2a prepper http t vpqtgeqlma ebay',
#  'erker eep thought yesterday saw hella scary hail armageddon',
#  'ahamedis think messiah come 125 years ago armageddon dajaal gog amp magog',
#  'sadly windows 10 reveals microsoft s ethics armageddon http t stftjcrjea',
#  'armageddon averted el patron ultimalucha',
#  'samihonkonen time 23 hours latest series ww1 blueprint armageddon extremely impressive',
#  'european fitba till christmas armageddon',
#  'christians united israel cufi jews convert soon die armageddon https t 4arwwrzpsr http t mkjq9yfmp8',
#  'official vid gt doublecups gt gt https t lfkmtzaekk gt gt trubgme prod thisizbwright gt gt armageddon',
#  'tomorrow day start armageddon preseasonworkouts',
#  'lee comedy \x89ûï leejasper working class tories prepare armageddon interestraterise\x89û\x9d',
#  '9 charts prove financial crisis 2 begun financial armageddon economic collapse blog tracks tren http t vhcxtvcinr',
#  'paul craig roberts \x89ûò vladimir putin issues major warning late escape http t nvfkzv5fex brics roberts russia',
#  'rohnertparkdps stage right lights isn t funny goofballs staff pd',
#  'official vid thereal gt gt gt https t 4i0rjc9rqu gt gt gt trubgme gt gt gt armageddon comin soon',
#  'celtic fingers crossed aberdeen tomorrow night armageddon eh',
#  'beyonce pick http t nnmqlz91o9 fan army beyhive http t o91f3cyy0r 77',
#  'direction pick http t q2eblokeve fan army directioners http t encmhz6y34 x1402',
#  '5 seconds summer pick http t j6wseptxga fan army 5sosfam http t qwgiwc9w7z',
#  '22 beyonce pick http t thoyhrhkfj fan army beyhive http t wvj39a3bgm',
#  '17 beyonce pick http t thoyhrhkfj fan army beyhive http t wvj39a3bgm',
#  'direction pick http t q2eblokeve fan army directioners http t encmhz6y34 x1411',
#  'seeing army whitewalkers thing slightly intrigued got far',
#  'build kingdom lead army victory https youtu start g friend code lzktjnox http t zz0cewew64',
#  'salvation army hosts rally reconnect fathers children salvation army hosting school rally\x89û http t rdjpor3azg',
#  'vote directioners vs queens 5th round billboard fanarmyfaceoff http t kgtxnnbj7y',
#  'build army 100 dogs leader lion dogs fight like lion',
#  'hero tv review http t kaccpk85wf http t nnixodhigc',
#  'direction pick http t q2eblokeve fan army directioners http t encmhz6y34 x1392',
#  'infantry mens lume dial army analog quartz wrist watch sport blue nylon fabric rea\x89û http t hep9k0xghb http t 80ebvglmra',
#  'direction pick http t q2eblokeve fan army directioners http t encmhz6y34 x1441',
#  'victorinox swiss army date women s rubber mop watch 241487 http t yfy3nkkcoh http t knehvvohvk',
#  'rt drayesha4 indiakomuntorjawabdo indian army ki\x89û http t wjljq3ya4g',
#  '5 seconds summer pick http t qchv3jqovk fan army 5sosfam http t gc0udfnfgg ìñ1',
#  'beyonce pick http t nnmqlz91o9 fan army beyhive http t o91f3cyy0r 78',
#  'direction pick http t q2eblokeve fan army directioners http t encmhz6y34 x1386',
#  'da mtvsummerstar videoveranomtv mtvhottest britney spears lana del rey',
#  'direction pick http t y9wvqkgbbi fan army directioners http t s5f9fcomp8',
#  'stony jackson america s hope leads army felons army rejects army o satan http t 0wbecdmhqo',
#  'wwi wwii japanese army navy military japan leather watch war mido ww1 2 read ebay http t f9j3l2yjl4 http t mwwwowcayo',
#  'beyonce pick http t nnmqlz91o9 fan army beyhive http t o91f3cyy0r 72',
#  '7 beyonce pick http t thoyhrhkfj fan army beyhive http t wvj39a3bgm',
#  'beyonce pick http t nnmqlz91o9 fan army beyhive http t o91f3cyy0r 66',
#  '6 beyonce pick http t thoyhrhkfj fan army beyhive http t wvj39a3bgm',
#  'potus appoints brig gen richard g kaiser member mississippi river commission learn mrc http t vdukcv7yjy',
#  'ap violent country army involved help control killings bring peace poor people',
#  'wwi wwii japanese army navy military japan leather watch war mido ww1 2 read ebay http t qumce7w2ty http t ktkg2sdhhl',
#  'wwi wwii japanese army navy military japan leather watch war mido ww1 2 read ebay http t obfd7e4qcp http t yazje5owvk',
#  'direction pick http t q2eblokeve fan army directioners http t encmhz6y34 x1434',
#  'direction pick http t imhfdaowrd fan army directioners http t 4ftzjk94dt',
#  'jewish terrorists charged historic church arson ugly truth http t ieksnfsby7 http t vwcf3slkrw',
#  'spokane authorities struggling solve arson cases like today s hamilton http t qbs2k01wzk http t mvlziysgll',
#  'thousands attend rally organized peace protesting arson attack took life http t bvckd9pdti',
#  'add familia arson squad',
#  'fake hate crime lesbians burn house new http t 66obqmximb',
#  'los angeles times arson suspect linked 30 fires caught northern http t xwms1aww8m newsintweets http t te2yerugsi',
#  'mourning notices stabbing arson victims stir \x89û÷politics grief\x89ûª israel http t eug6zhciun',
#  'mourning notices stabbing arson victims stir \x89û÷politics grief\x89ûª israel http t kkbxiblah7',
#  'sound arson',
#  'owner chicago area gay bar admits arson scheme http t myhohvrhil lgbt https t tm5hthfdo0',
#  'wait http t uavfrtlfs4 http t 85g1pcccxg',
#  'arson suspect linked 30 fires caught northern california http t ej2ghnafhy',
#  'trial date set man charged arson burglary http t wftcrlz32p',
#  'death palestinian toddler arson attack israel cracks jewish',
#  'palestinian teen killed amid protests arson attack http t okvsimogic',
#  'kisii police kisii hunt students failed arson plot police kisii hunt students http t m5sbfrrsn7 countynews',
#  'mariah getting shoulders poor girl',
#  'mourning notices stabbing arson victims stir \x89û÷politics grief\x89ûª israel posters shira banki http t 3gz5zqqthe',
#  'relaxinpr miprv rt latimes arson suspect linked 30 fires caught northern california http t ylhayfaoou',
#  'jewish leaders prayed hospital palestinian family treated arson http t wf8itk2kvx huffpostrelig',
#  'owner chicago area gay bar admits arson scheme http t 0tslqjokvh theadvocatemag lgbt',
#  'sayn ae angel arson',
#  'kisii police kisii hunt students failed arson plot police kisii hunt students http t 5bdrfu1duo countynews',
#  'mourning notices stabbing arson victims stir \x89û÷politics grief\x89ûª israel http t q4l7dg56jm',
#  'owner chicago area gay bar admits arson scheme http t 2y9dnp5vtg theadvocatemag lgbt https t 6xul6dcosh',
#  'owner chicago area gay bar admits arson scheme http t ubfr1urafc lgbt https t alnv51d95x',
#  'mourning notices stabbing arson victims stir \x89û÷politics grief\x89ûª israel http t gbluhrrlto',
#  'owner chicago area gay bar admits arson scheme http t zpxe3fmyng lgbt',
#  'arson suspect linked 30 fires caught northern california http t wnuqqatttp latimes',
#  'tennessee lesbian couple faked hate crime destroyed home arson\x89û http t 10muey8pxj lesbian',
#  'arson suspect linked 30 fires caught northern california los angeles times http t prrb4fhxtv',
#  'arson suspect linked 30 fires caught northern california http t u1fuwrgk5u',
#  '301dc cloudy goldrush hate white people mo',
#  'nowplaying arsonist mc impressed arsonistmusic http t 1elreh1jlj',
#  'alleged east bay serial arsonist arrested http t wr48aqtum7',
#  'safyuan minor citation possesion decriminalized substance im facing time',
#  'suspected serial arsonist arrested calif http t pzotpdgaki',
#  'arson suspect linked 30 fires caught northern california http t mmgsyahdzb',
#  'local arsonist diamorfiend legal forgets',
#  'casper rmg u dick',
#  'bloor ossington arsonist burned mattress northumberland st cbcto http t wpdvt31sne',
#  's arsonist',
#  't nice come sit',
#  'vegetarian vegan video shows arsonist torching popular bk restaurant strictly vegetarian http t kxplyom9rr govegan uniteblue',
#  'arsonist arrested setting fires watch tonight\x89ûªs headlines http t sqgogj3s5r nightbeat veronicadlcruz 2minutemix',
#  'video captures man removing american flag long beach ca home burning arsonist sought http t jp2qlrunjj http t jbpgkgowsi',
#  '58hif trick think nasty things',
#  'spotlight paradise arsonist mc wniagospel http t 1he4ufawzm arsonistmusic http t bnhtxaezmm',
#  'makes http t 28t3nwhdky',
#  'town salem melted ice cube bc im arsonist d',
#  'arsonists blamed blaze plastics recycling business adelaide pcaldicott7 reports 7newsadl http t r1xwdnvb0g',
#  'hotboy shit',
#  'zodiac girl feat trey dupree produced sparkz beatz chuck da arsonist http t hdkd9j2lw0',
#  'local arsonist lmfao',
#  'alleged east bay serial arsonist arrested sanfrancisco http t ojuhfkhvb2',
#  'doofus diamorfiend im jokin moves',
#  'local arsonist guess u s shit thinking',
#  'arsonist sets nyc vegetarian restaurant police newyork http t nr7ust3uh8',
#  'liked youtube video slimebeast http t ulr6myklnh town salem win arsonist',
#  'casper rmg bestcomedyvine whats cracking cuz',
#  'smoke good fuck eat drink drive nice car wear green mink',
#  'kill got court day earl',
#  'local arsonist lmao real live',
#  'owner chicago area gay bar admits arson scheme frank elliott pleaded guilty hiring arsonist http t jcfehrhlq8',
#  'trusting iran stop terrorism like inviting arsonist join brigade telegraph http t 2z2htdjqzd',
#  'big burning true story arsonist missing girl \x89û http t qxh1h61cwd',
#  'stay vigilent civil liberties constant attack nativehuman myreligion https t wwu070tjej',
#  'credit pfannebeckers inspiring rediscover fantabulous tbt http t wmhy47xkil',
#  'http t ptkrxtzjtv nashville theater attack gun grabbers demand \x89ûïhatchet control \x89û\x9d',
#  'breaking terror attack police post udhampur',
#  'demi stans think heart attack sold 5 6 million copies',
#  'scares s new versions nuclear attack warnings like knowing governments prepare',
#  'isil claims suicide bombing saudi mosque killed 15 http t y8icf89h6w http t t9msnzv1kb',
#  'dattomm funniest twitter feminists try attack 4head',
#  'horrific attack wife muslim italy http t ny3l1orzqb liveleak news',
#  '\x89ûª93 blasts accused yeda yakub dies karachi heart attack http t mfkqyxd8xg mumbai',
#  'etribune drone attack kills 4 suspected militants north waziristan acebreakingnews https t jb038rdfak',
#  'suspect latest theater attack psychological issues http t 3huhzxliig',
#  'militants attack police post udhampur 2 spos injured livemint http t rptouz2ijs http t 69mlhfefhr allthenews',
#  'breaking obama officials gave muslim terrorist weapon texas attack http t qi8qdw5dfg',
#  'delhi government provide free treatment acid attack victims private hospitals http t h6pm1w7ell',
#  'new post darkreading http t 8eijdxapnp new smb relay attack steals user credentials internet',
#  'israeli forces raid home alleged car attack suspect http t 3gvus8nppy palestine',
#  'heart attack thought goat dead t worry rocket okay',
#  'm gonna lie m kinda ready attack senior year',
#  'left hand diamond graveyard shift attack defend right handside fucking idiot',
#  'volleyball attack ii volleyball training machine sets simulation http t dcdecfv934 http t dwbc1duvdk',
#  'notley s tactful direct response harper s attack alberta s gov t hell yeah premier http t rzsulzmokx ableg cdnpoli',
#  'police assailant latest movie theatre attack homeless psychological issues http t zdcvlyq6qk',
#  'caixxum5sos thanks damn heart attack',
#  'suspect latest theatre attack psychological issues http t onpnbx0zex http t um5icn5et2',
#  'india shud evidence 2 pak share terrorists amp use attack share oth contries https t qiopbtiuvu',
#  'illegal alien released obama dhs 4 times charged rape amp murder santa maria ca woman prior offenses http t mqp4hf9gpo',
#  'strongly condemn attack ary news team karachi cowardly act simply trying job',
#  'nashville theater attack gun grabbers demand \x89ûïhatchet control \x89û\x9d http t oyogii97yh',
#  'fact atomic bombs called little boy fat man says lot mentality went attack',
#  'blazerfan ignoranceshe latinoand benothing morebut attack dog 4 hate group gop',
#  'heart disease prevention secondhand smoke http t ydgmgbryl2',
#  'dayton area org tells hit cyber attack http t 7lhkjz0ivo',
#  'attack titan game ps vita yay t wait 2016',
#  'infowars nashville theater attack gun grabbers demand \x89ûïhatchet control \x89û\x9d http t n3yjb8tcpm nwo',
#  'anxiety attack',
#  'dog attacked food pugprobs',
#  'cop injured gunfight militants attack udhampur police post suspected militants attacked police post http t 2h0dpmv2ef',
#  'envw98 nickcocofree juliedicaro jdabe80 asked feel attacked julie asked frail',
#  'messeymetoo feel attacked',
#  'm feeling attacked https t cvkqigr1az',
#  'black men t way white men black men getting attacked https t chkp0gfynj',
#  'believe fucking cis female going claim offended transgendered female s attacked media',
#  'israeli helicopters attacked civilians gaza completed exercises greece',
#  'christian attacked muslims temple mount waving israeli flag pamela geller http t 5qyczywkgg',
#  'christian attacked muslims temple mount waving israeli flag pamela geller http t u0keoe5fmt',
#  'christian attacked muslims temple mount waving israeli flag pamela geller http t f5miuhqaby',
#  'pt unit attacked responsible targeting muslim scholars imprisoning youth http t f4lhfmehzh',
#  'telnet attacked 124 13 172 40 streamyx home southern',
#  'christian attacked muslims temple mount waving israeli flag pamela geller http t wgwiqmicl1',
#  'tbt remember time patrick kane attacked cab driver 20',
#  'im feeling attacked http t 91jvycxxvi',
#  'ik troll pol rivals literally abused attacked families literally abuse ik loosers',
#  'christian attacked muslims temple mount waving israeli flag pamela geller http t nhxse3rthx',
#  'christian attacked muslims temple mount waving israeli flag pamela geller http t lhbzhwq4b9',
#  'envw98 nickcocofree juliedicaro jdabe80 worst person questioning julie attacked guys empathy',
#  'kelly osbourne attacked racist donald trump remark latinos view http t 7nagdsadwp',
#  'eunice njoki aiii needs chill answer calmly like s attacked',
#  'christian attacked muslims temple mount waving israeli flag pamela geller http t mxz7yx8ld1',
#  'christian attacked muslims temple mount waving israeli flag pamela geller http t e4ydbm4dx6',
#  'christian attacked muslims temple mount waving israeli flag pamela geller http t t1aa5ov7eg',
#  'attacked robot lvl 19 ve earned total 6615434 free satoshis http t dmlj1agotw robotcoingame bitcoin freebitcoin',
#  'christian attacked muslims temple mount waving israeli flag pamela geller http t emdjnnltp0',
#  'christinalavv lindsay wynn3 saw tweets feel attacked',
#  'christian attacked muslims temple mount waving israeli flag pamela geller http t a6wmbnr51s',
#  'christian attacked muslims temple mount waving israeli flag pamela geller http t etg0prbp4g',
#  'christian attacked muslims temple mount waving israeli flag pamela geller http t yubkhf9iyh',
#  'tv program saw said air plane flew uranium fukushima attacked machine gun student army digging',
#  'christian attacked muslims temple mount waving israeli flag pamela geller http t e4wk8uri8a',
#  'mageavexis lt things attacked',
#  'christian attacked muslims temple mount waving israeli flag pamela geller http t 1pdjoq4jc1',
#  'welovela nhlducks avalanche defense match vs st louis blues http t 9v1rvcomh2 sportsroadhouse',
#  'liked youtube video http t tnxquor1wb kalle mattson avalanche official video',
#  'll crash like avalanche',
#  'colorado avalanche men s official colorado avalanche reebok t shirt xl blue 100 cotton http t znsvstgwx3 nhl hockey',
#  '2 tix 10 3 frozen fury xvii los angeles kings v avalanche 103 row aa mgm grand http t kbtzzzg2tp',
#  'bet didnt know kick box https t rbrw8pwipj',
#  'little piece wrote avalanche designs blog d appreciate greatly checked https t rfvjh58ef2',
#  'patrick roy 1998 99 upper deck spx 171 finite 1620 colorado avalanche mint http t uhfm1r3tq5 http t qulgakebhb',
#  'musician kalle mattson recreates 34 classic album covers clever music video avalanche http t ydjpoph1dw',
#  'beautiful sweet avalanche faith akito roses lots frothy gyp http t raqupzfkjy weddinghour http t qunxocxcga',
#  '1 6 tix calgary flames vs col avalanche preseason 9 29 scotiabank saddledome http t 5g8qa6mpxm',
#  'secrets avalanche catechize inner self confidential communication respects creating worth len',
#  'fall leaves poplar fully ordained tumbling avalanche spurgeon',
#  'saw great punk bands making original music week check em ghostoftheav montroseband https t wdvxjsqwic',
#  'great performance chip fuel gas saver chevy tahoe blazer avalanche s 10 http t icrzi5tqc5 http t onxhkfhn2a',
#  'musician kalle mattson recreates 34 classic album covers clever music video \x89û÷avalanche\x89ûª http t vbswhz4s2v',
#  'driving avalanche having car week like driving tank',
#  'free ebay sniping rt http t rqipgqslt6 chevrolet avalanche ltz lifted 4x4 truck favorite amp share',
#  'chiasson sens t come deal coloradoavalanche avalanche http t 2bk7lagma9 http t bkdgcfsuiq',
#  'paul rudd emile hirsch david gordon green prince avalanche q amp filmmakers google http t e4qonkzndz entretenimento video',
#  'great time deal avalanche music purchase neal rigga shirt http t 4virxkgmpc',
#  'bigperm28 drafted avalanche 2005 rd 4 124 overall played season utahgrizz http t gpgtafmkt0',
#  'got videos rappers got songs http t pblvpm6c27',
#  'funkflex yo flex im https t 2azxdlcxga',
#  'avalanche world away believing m wide awake',
#  'possible new jerseys avalanche year http t nruzhr5xqu',
#  'feat watch bts kallemattson s incredible music video avalanche https t 3w6sea9tuv',
#  'avalanche city sunset http t 48h3tlvlxr nowplay listen radio',
#  'chevrolet avalanche lt 2011 lt 5 3 l v 8 16 v automatic 4 wd pickup truck premium b\x89û http t obky8pc89h http t dxirntdsrd',
#  'snowflake avalanche feels responsible',
#  'star wars power jedi collection 1 battle droid hasbro read ebay http t xfguklrltf http t fegu8hwmc4',
#  'civil war general battle bull run hero colonel 2nd new hampshire letter signed http t ot0tffpbyb http t zarbwep9ld',
#  'dragon ball z battle gods 2014 rotten tomatoes http t jddnhmrmmj rottentomatoes',
#  'added video youtube playlist http t wedwyn9kfs world tanks battle assistant mod bat chat arti kaboom',
#  'ya boy clip vs 4kus battle 15moferadio heavybag201 battle dom qotring battlerapchris hughes1128 https t 7spydy1csc',
#  'fully aware battle support fight https t mctjnzx4h8',
#  's baaaack petersen s bowhunting battle bows sure head cast vote http t fj73gdvg2n',
#  'tb throwback want battle s war https t b0zjwgmaiw',
#  'kelby tomlinson mild mannered 2nd baseman great metropolitan team fights ending battle hits rbi sfgiants way',
#  'black eye 9 space battle occurred star m27329 involving 1 fleets totaling 1236 ships 7 destroyed',
#  'happened taken king story trailer space battle ripped hole saturn eytay neur0sis http t zyrzx6dfki',
#  'battle animations fucking',
#  'happens battle block cbsbigbrother finally',
#  'du19 gon rap battle',
#  'thing battle internal vs external motivation http t w9p3hauhei',
#  'check item got phantasmal cummerbund http t qrhjei7grq warcraft',
#  'young german stormtrooper engaged battle somme 1916 800 ìñ 582 http t yxvmiflvc4',
#  'liked youtube video http t 9vw0uqqi1y marvel vs dc avengers battle',
#  'utahcanary sigh daily battle',
#  'sexydragonmagic ve come realization t attention span mass battle games painting playing',
#  'detroitpls interested win battle',
#  'battle goats https t ofecs6tcvc',
#  'star wars power jedi collection 1 battle droid hasbro read ebay http t yi30zgizsw http t 2jgvhw7yzs',
#  'black eye 9 space battle occurred star o784 involving 2 fleets totaling 4103 ships 50 destroyed',
#  'lonepine remembered australia descendants grow 666canberra gallipoli ww1 http t t4fvvnrpc5 http t 0zznbvfuvo',
#  'miss gary busey s son plays dixie electronic green fiddle post battle celebration sequence',
#  'news fedex longer transport bioterror germs wake anthrax lab mishaps http t xtezgjfs8a',
#  'fedex longer transport bioterror germs http t qfjjdxes7g usatoday',
#  'usa today fedex longer transport bioterror pathogens http t iadlslqdpd newsintweets http t o8y1sul4ow',
#  'fedex longer transport bioterror germs wake anthrax lab mishaps http t hqsu8lwlth usatoday',
#  'jacksonville busines fedex stops shipping potential bioterror pathogens http t shzsymausi',
#  'fedex longer transport bioterror pathogens wake anthrax lab mishaps http t lhpgxc4b8j',
#  'aphl responds fedex longer transport bioterror germs wake anthrax lab mishaps http t cgdj3drso9',
#  'news fedex longer transport bioterror germs wake anthrax lab mishaps åêfedex http t k0y7xfxmxa tcot',
#  'fedex stop transporting bioterror germs lab mishaps fedex stopped transporting certain research http t y3dm9ulqxg',
#  'fedex longer ship potential bioterror pathogens http t chorr2xovp atlbizchron',
#  'frontpage bioterror lab faced secret sanctions rickperry t cut foxnews gopdebate http t fzujg7sxjg usatoday',
#  'fedex longer transport bioterror germs wake anthrax lab mishaps http t qzqc8wwwcn usatoday',
#  'house energy amp amp commerce subcommittee hold 7 28 hearing cdc oversight bioterror labs army anthrax mishaps htt\x89û',
#  'fedex willing transport research specimens potential bioterror pathogens wake anthrax lab mishaps http t cm8uni1mrg',
#  'world fedex longer transport bioterror germs wake anthrax lab mishaps http t wvexjjrg6e',
#  'fedex longer transport bioterror germs wake anthrax lab mishaps http t p96rgbbayl news phone apple mobile',
#  'rt alisonannyoung exclusive fedex longer transport research specimens bioterror pathogens wake anthrax lab mishaps \x89û',
#  'hmm problem researchers fedex longer transport select agents http t 9viibxgjav usatoday',
#  'world fedex longer transport bioterror germs wake anthrax lab mishaps http t 5zdbtktww7',
#  'fedex longer transport bioterror germs wake anthrax lab mishaps http t pwamg8ozj4',
#  'fedex longer ship potential bioterror pathogens fedex corp nyse fdx longer deliver packages http t 2kdq56xtws',
#  'fedex longer ship potential bioterror pathogens atlanta business chronicle http t yllqjljiiq',
#  'thank fedex longer shipping live microbes department defense http t zahnewjri8',
#  'nowplaying orchardalley les nyc bioterror manufactured fear state repression abcnorio gardens http t ba2rrxugsg',
#  'fedex longer transport bioterror germs http t shrhkfj1bc usatoday',
#  'jax biz journal fedex stops shipping potential bioterror pathogens http t r33ncvjovc',
#  'usatoday today s frontpage bioterror lab faced secret sanctions rickperry t cut foxnew\x89û http t 5ukohk7sob',
#  'breakingnews http t gan14pw9tg fedex longer willing transport research specimens potential bioter\x89û http t 5n4husewly',
#  'fedex longer transport bioterror germs wake anthrax lab mishaps http t c0p3sesqwm usatoday',
#  'fedex stops shipping potential bioterror pathogens http t tkeoaedqkq trucking',
#  'fedex longer transport bioterror germs wake anthrax lab mishaps http t mqbyravk6h',
#  'fedex longer transport bioterror germs wake anthrax lab mishaps http t s4sicmyrmh',
#  'fedex longer shipping bioterror germs wxia tv scoopit http t zqqjrqsbjm',
#  'fedex longer transport bioterror germs wake anthrax lab mishaps http t hrqcjdovjz',
#  'usatoday today s frontpage bioterror lab faced secret sanctions rickperry t cut foxnew\x89û http t xfhh2xf9ga',
#  'fedex longer transport bioterror germs wake anthrax lab mishaps http t 4m5uheyfdo usatoday',
#  'biolab safety concerns grow fedex stops transporting certain specimens research facilities dumbfounded action http t rujv4vpnbv',
#  'fight bioterrorism sir',
# ...
#  'blew mentions',
#  '1st time blew phone 30 times blocked believe catfish',
#  'imawesome7986 like literally blew',
#  'freyas video blew',
#  'yahooschwab easy way look good ray rice fiasco blew',
#  'lmao light skin guy blew twitter talking ugly kid',
#  'watched honey blew economy recommend conservative shoppe horrors harperanetflixshow elxn42 stopharper',
#  'fireball falling earth look like plane blew',
#  'ye thing big sean blew',
#  'zayn blew twitter',
#  'bitch blew shit',
#  'weloverobdyrdek adrian peel damn clue tried clicks blew s played',
#  'daorcey nsit great pair like couple graywardens fighting blight',
#  'damidnighter theres actually theory magisters arent reason blight dwarves ones',
#  'cycling fan feel sorry world athletics doping blight exacerbated monetary reward lot soul searching required',
#  'kynespeace blight',
#  'poor jack',
#  'realhotcullen agree knew d going deep roads blight red lyrium ain t gt gt',
#  'load welfare loving sponge blight society http t rrzbzgo48n',
#  'new post prysmian secures contract blight bank wind farm http t olg09kb6ha',
#  'cleveland heights shaker heights fight blight house door http t wyokt0ftrw',
#  'todd calfee mattburgener wanted info blight u got',
#  'carl everest rob cobes whitt blight frost leo snuff godly drink beer someday',
#  'thda kicks anti blight loan effort memphis http t xzlrwc0pik http t o5xlxmkoyq',
#  'city program help turn blight greenspace tennessee housing development\x89û http t zzcbbqyj1q news http t kksghsblfh',
#  'demetae12 yes want new blight leader',
#  'releases planing level 1 constellation blight gaia iclown s drumstep remix 2 iclown infinity http t 7le5gq2psx',
#  'http t etkd58un8n cleveland heights shaker heights fight blight house door http t lrelvrm06w',
#  'going achieve excellence big things develop habit little matters dont know author',
#  'hendy 21 sure purdies alive blight',
#  'tracy blight thank following',
#  'apperception bridgework blight xxhjesc http t ybhbarajxp',
#  'dotish blight car right ahead s',
#  'sexual revolution blight women http t t8sv2ai7sw stories acebabes healthweekly1 amateurnester',
#  'like swear secret ll uncover old gods slumber think theres gonna blight',
#  'willhillbet double result live app',
#  'parksboardfacts zippoline wants use community asked blight park moveit',
#  'look policy matters ohio report cle cuyahoga county blight greening vacant lands soon https t if62sdxvp7',
#  'anellatulip taint magisters open gates let blight away',
#  'anellatulip theory makes way sense says dwarves actual origin blight',
#  'palestinian refugee tragedy blight humanity amp shame israeli living https t gaae0no5du',
#  'article michael jackman metro times detroit group later downgraded estimate 37 square miles http t h31mmuduqt',
#  'locksmithing art respecting elaboration blight locks lpdkl',
#  'jake blight wealilknowa cunt',
#  '5000 wins ranked play gave special card cool long te\x89û http t vq3yab2j8n',
#  'amazon deal wait buy http t 0t8vqkeari',
#  'new print available http t ucy5fea9yu waiting long pamela blizzard http t dnwwo1ybrk',
#  'blizzard draco free art kamon',
#  'stevenontwatter pussyxdestroyer order blizzard pay nuts ball flavored boom free ice cream',
#  'blizzard auz 9 pm cst radioriffrocks http t pjlda9hd5v 2 hrs rock hump day complete http t 3wnjauar7w',
#  'wants rolo blizzard mom said guess dq tonight',
#  'ashayo msmiggi hi ashayo believe vods youtube presentation like seeing live',
#  'stats http t u7vavyrgv9',
#  'tweet4taiji dolphin worship group based superstitions look tweets',
#  'blizzard fans lucio let s overwatch hype train rolling caution aren t breaks',
#  'blizzard gamin ight',
#  'peanut butter cookie dough blizzard',
#  'mic controllers aren t working second',
#  'tomorrow s announcement vods http t cubze5mizm',
#  'updated windows 10 error http t khsbzkfd6o',
#  'new expansion ideas bard class holy trinity 1 http t egioxbaboe',
#  'daborsch shocking blizzard lured old fanbase wod disappointed hardcore everyones leaving',
#  'best thing dq cotton candy blizzard',
#  'lizard wizard blizzard lwb http t mgr809yc5a',
#  'blizzard draco lonewolffur need',
#  'fairx818x playoverwatch blizzardcs blizzard love',
#  'blizzard clutch asf',
#  'blizzard draco lonewolffur like link',
#  'bubblycuteone ok ok okayyyyyy ima act right bout blizzard tho',
#  'lonewolffur control tora',
#  'time playing hearthstone pc thoughts http t abolxmh1vy',
#  'love cotton candy blizzard',
#  'tcgreno hard reset xbox',
#  'wanna brownie batter blizzard',
#  'little bit blizzard',
#  'market news activision blizzard cognizant technology solar http t gknrp0e8qs',
#  'sean end career sg blizzard vs knockout http t nyv51681ue',
#  'biggest regret hearthstone http t vcirn1md8v',
#  'walk dq wanna butterfinger blizzard bad',
#  'horrible moment u open dryer looks like snowy blizzard cuz u left piece paper jeans pocket',
#  'lonewolffur bruh dies',
#  'rip blood',
#  'chief cg nah young blood cook gone m cut haha',
#  'wall invincible history blood dance floor https t zntg2wndmj',
#  'broke nail real fake morning blood ah hurts ideas treat help pretty',
#  '4 5 5 stars 290 reviewers dragon blood boxset lindsay buroker http t 4yu5sy1cui kindle http t mzmxmyklxv',
#  'blood group ve associated gastric carcinoma says text book fragile gene body',
#  'friend like blood come wounded',
#  'gone blood',
#  'people tattoo u allowed donate blood receive blood',
#  'dialyses grandpa oh lord blood makes light headed',
#  'setzorah dad dont claim mean right look eyes blood xbox 360 smh',
#  'omron hem 712c automatic blood pressure monitor standard large bp cuffs http t gjbainqwn9 http t jphgpl1c5x',
#  'blood pressure roof t need extra shit',
#  'chambered blood yeah speakingfromexperience',
#  't believe people mid 20 s t high blood pressure life stressful decisionsondecisions',
#  'guys imouto isn t actually related blood',
#  'bruh white people buy ugliest shoes super tight blood going feet',
#  'day excellent dangerousbeans porridge seriously people blood orange porridge phenomenal',
#  'scotto519 happy birthday young blood',
#  'wasn t blood',
#  'kinda shii nasty blood pun intended',
#  'ain t hoe blood',
#  'today hastle getting drug tested blood drown tb shot document filling',
#  'man somebody gotta stop sbee dude fuckin funny blood',
#  'winds gypsy blood time http t 66yvulizbk',
#  'lobo paranoico mad men',
#  'private thirsty night sad blood rock n roll',
#  'rolandonabeats ellie goulding blood acesse nosso site para ouvir http t zk69ugxmt8',
#  'olrules welcome read free chapter new book encounters jesus s hope http t 6qx7arf4ag',
#  'anthxvy runs blood',
#  'sethalphaeus personal favorites include paramore muse green day royal blood 5sos',
#  'shed innocent blood sons daughters land polluted psalms 106 38 help stop sin abortion',
#  'se pone cantar crying lightning',
#  'wasnt big stab deep stab theres like blood everwhe',
#  'add items everyday eating habits research blood\x89û https t lnpscadaxr',
#  'looooooooooool bloody hell https t jrkgyl7te5',
#  'infected bloody ear piercings fun',
#  'aggressif bloody aggressive',
#  'entered win entire set butterlondon lip crayons ram0s enter bbloggers http t dsb3ldfuxu',
#  'slsandpet hey sally sorry emailed awol bloody work argh resigninshame',
#  'm listening bloody jay https t ciyty0fgpr',
#  'lauradeholanda forrest version 83 s bloody awful xxx',
#  'nightmare elm street getting remade http t hvwkjqxxyt',
#  't bloody wait sony sets date stephen king\x89ûªs \x89û÷the dark tower\x89ûª stephenking thedarktower http t j9lpdrxcde bdisgusting',
#  'gotta try let bloody things smh',
#  'tradcatknight 1 russia played reason link bs okanowa bloody mainline invasion looked like bloody',
#  'bloody insomnia grrrr insomnia',
#  'zhenghxn tried 11 eyes akame ga kill tokyo ghoul damn bloody dont dare watch',
#  'fantosex suck s bloody getting means amends',
#  'weekends bloody mary times summer s new\x89û https t vnni3zzuz6',
#  'bloody hell day haven t tired thought vaca help',
#  'damn bloody hot',
#  'mrtophypup s bloody sexy drools',
#  'know effects low amp fast son product acne cream 1 effects bloody diarrhea',
#  'ronda rousey close making floyd mayweather s money 50 fights bloody elbow http t ijzcytbffo boxing',
#  'm awful painting agree a3 landscape bloody oils paints',
#  'need life sin girlfriend ride till bloody end girlfriend',
#  'itsmegss think s bloody barking',
#  'eh hello cover bloody thighs bloody cleav \x89ûó eh hello expose cleavage http t kv5l4ppxfg',
#  'mariasherwood2 johnjcampbell mega bloody marvellous',
#  'bloody mary sink beet juice http t luigmhma1i',
#  'melrises gayler1969 wwwbigbaldhead jessienojoke melissaross9847 monty python date bloody far wants',
#  'meet bloody rs5 http t rvczmimfvx',
#  'friday supposed happy day s bloody friday hah zzzz',
#  'chxrmingprince jones luna bloody hope said folding arms sitting chair',
#  'wait tell college friend reafs bloody mary drama cd',
#  'came kill indians fun video smirking remorseless pakistani killer shows boasting http t fpjlwoxklg',
#  've watched episode s01e09 bloody monday http t vrpthvpymt bloodymonday tvshowtime http t nkkvknbvoz',
#  'marlon williams gt elvis presley gt marlon williams gt steel panther shuffle mode like bloody legend',
#  'black friday turns bloody shopping http t l0pmmtzlwp mystery',
#  'ezralevant told soccer moms getting pic blown daughter s bedroom walls',
#  'papcrdoll s2g mentions blown choice deactivate leave good respect choices',
#  'manutd emilymcfcheslop wow wow club blown money fucked player like d pilloried',
#  'damn greinke got blown inning',
#  'woke blown lol',
#  'aunt marge blown eheks',
#  'troylercraft yeah worth bc spammers amp twitter probably blown second',
#  'white family supposedly representing america s great values gets blown horrible cgi nuclear strike lmfaoooo',
#  'man hasn t machinegunkelly blown s underground',
#  'mentions blown wtf',
#  'thisdayinhistory 1862 confederate ship blown crew read http t iw7elszifz history',
#  'moment ur win mini uhc blown creeper kicked flying salty rn',
#  'libraryeliza taylorswift13 bump approval probably s blown http t kolmzbz1pz musicadvisory',
#  'truckload soldiers blown panics little lion dies loses mind http t wjntaokdhf',
#  'hey look kash s foundation live today got blown people magazine s website todd blake http t 2fenu1syu6',
#  'kaylak369 got month went ee shop glad hasn t blown http t pgb2bmcfx8',
#  'time tweet blown half day later https t 1buf0xm53d',
#  'we\x89ûªre blown away extension we\x89ûªve seen options https t 0yzgw9zbhr https t rhtaqjvqn2',
#  'theboyofmasks thanks letting stay manor blown anyways buddy',
#  'loner diaries patterns sand blown away photos twos choked flames http t ekfaz6wvbz',
#  'bsg sufficiently hyped years delayed watching utterly utterly blown away',
#  'vanessa s game officially blown ladies gentlemen real begin bb17',
#  'guaranteed bitten mutant mosquito ankle blown little cunts',
#  'things pick tozlet seat butt leprosy blown jerkface syndrome lateral lisp amp toilet rickets',
#  'kalinandmyles kalinwhite ig blown hackers need stop givebackkalinwhiteaccount',
#  'luke winkie directing videos needs grab nicki minaj u s recognition minds blown',
#  'princessduck week wanted 6th sense blown far good james win s huge target gone soon',
#  'orbette like blown amirite',
#  'dog\x89ûªs blown kennel \x89ûò bloody yorkshire terrorist',
#  'turn espn2 blown',
#  'hopefulbatgirl went beaten blown thing know ra al ghul brought life escaped',
#  'thebriankrause leos ass got metaphorically blown piperwearsthepants charmed',
#  'anarchic teapot boironusa zeno001 glononium 6c helps blown bashing bottle nitroglycerin book',
#  'new ladies shoulder tote handbag women cross body bag faux leather fashion purse re\x89û http t y87gi3brlv http t 1zbhvdcxzs',
#  'new ladies shoulder tote handbag women cross body bag faux leather fashion purse re\x89û http t blaawhysct http t ddr0zjxvqn',
#  'son daughter like going war iran come body bag let republicans know',
#  'questergirl ditto way feel drank vodka ice body bag',
#  'handbags genuine mulberry antony cross body messenger bag dark oak soft buffalo leather å£279 00end date w http t ftm4rkl8mn',
#  'louis vuitton monogram sophie limited edition clutch cross body bag read ebay http t jrxgolnpqw http t lin16kvzbn',
#  'louis vuitton monogram sophie limited edition clutch cross body bag read ebay http t gggfvo5pb4 http t nlfr8t3xqm',
#  'louis vuitton cultsierre monogram shoulder bag cross body bag http t muf5czqjrl http t sslt8esmhy',
#  'check ameribag healthy bag shoulder cross body backpack khaki tan beige nylon http t r4k7tylofj ebay',
#  'photo bath amp body works cosmetic bag periwinkle blue copper piping corners http t a9bnlse6qb',
#  'new ladies shoulder tote handbag women cross body bag faux leather fashion purse re\x89û http t 3pcntczoxv http t n0akjm1e4b',
#  'new summer long body bag hip word skirt blue http t lvkoemsq8m http t cjirhhh4vj',
#  'å¤ new ladies shoulder tote handbag faux leather hobo purse cross body bag womens http t uoozxaus26 http t 6mgbizjfgd rt en\x89û',
#  'tr jdavis bruh wanna fight m meet cage bro better dealing end body bag',
#  'new ladies shoulder tote handbag faux leather hobo purse cross body bag womens read\x89û http t 4fxfllrien http t i12nlsr8fk',
#  'auth louis vuitton brown saumur 35 cross body shoulder bag monogram 7 23 419 3 read\x89û http t hcdiwe5flc http t zlvebeoavg',
#  'check vintage longaberger floral fabric shoulder cross body bag brown leather strap http t fb8snrg4hu ebay',
#  'new ladies shoulder tote handbag faux leather hobo purse cross body bag womens http t zujwuiomb3 http t gbctmhx7pw',
#  'new summer long body bag hip word skirt blue http t 8jymd9ypsj http t 57pkmmcadg',
#  'ìü new ladies shoulder tote handbag faux leather hobo purse cross body bag womens http t uoozxaus26 http t pw78nbljky rt en\x89û',
#  'louis vuitton monogram sophie limited edition clutch cross body bag read ebay http t i4aogcsoy5 http t djiwg9pxv4',
#  'new women handbag faux leather ladies shoulder tote cross body bag large satchel re\x89û http t ncjpgf6znv http t gerjau74ey',
#  'new ladies shoulder tote handbag faux leather hobo purse cross body bag womens http t zujwuiomb3 http t iap4lwvqsw',
#  'day heart gone zipped body bag',
#  'handbag fashion style http t ipxpi3me16 authentic louis vuitton pochette bosphore shoulder cross body bag\x89û http t rv0fk7q4y5',
#  'å new ladies shoulder tote handbag faux leather hobo purse cross body bag womens http t zujwuiomb3 http t ykltfj1fnc',
#  'handbag fashion style http t hpd3snm6oy vintage coach purse camera bag cross body 9973 16 99 0 bids \x89û http t gsmddmu9pu',
#  'genuine leather man bag messenger fit ipad mini 4 tablet case cross body air jp rea\x89û http t rcburzsb2b http t ehsfklgri3',
#  'louis vuitton monogram sophie limited edition clutch cross body bag read ebay http t vjgr6liaxh http t 55jr66plov',
#  'new ladies shoulder tote handbag faux leather hobo purse cross body bag womens http t zujwuiomb3 http t cjqq6cgohg',
#  'nuu fam fwt m leave body bag',
#  'new ladies shoulder tote handbag faux leather hobo purse cross body bag womens read\x89û http t ur7fexszg4 http t wb8awoblcl',
#  'rhee1975 deliciousvomit m m saying lucky home families body bag',
#  'matt bez oh m bagging body bangin m saying s going rose',
#  'ohmyloz rondarousey bagging body s smoking hot',
#  'drake body bagging meek',
#  'fuckyeahcarey bornverified drake killing dude tea bagging dead body point',
#  'meekmill w rec k league ball drake olympic level body bagging like career trollingtilmeekdiss',
#  'idgaf tough canada north philly meek acting like bitch amp drake body bagging ass tracks',
#  'yankees body bagging mfs',
#  'broseidonrex dapurplesharpie skimmed twitter missed body bagging',
#  'g https t dodxi41y1cåêis body bagging lyrically https t hlmyaanrc9',
#  'bomairinge elutranscendent straight body bagging',
#  'body bagging bitches http t afssgpnzwi',
#  'better feeling seeing stage day ones 22 year friendships body bagging mics',
#  'mopheme bigstar johnson problem game body bagging niggas vuzuhustle',
#  'body bagging today 4got post score http t 81g18wsauk',
#  'editaxohaze let bagging body s begin lol ain t cuffed shouldn t bad',
#  ...]

# %% [markdown]
# ## Split data into TRAIN and TEST sets

# %%
X_train_list, X_test_list, y_train_list, y_test_list = train_test_split(cleaned_tweets_lst, initial_df['target'], test_size = 0.3, random_state = 42)

# %%
print(type(X_train_list))
print(X_train_list)
# Out:
# <class 'list'>
# ['ashes 2015 australia\x89ûªs collapse trent bridge worst history england bundled australia 60 http t t5trhjuau0', 'great michigan technique camp b1g thanks bmurph1019 hail youtsey termn8r13 goblue wrestleon http t oaskgki6qj', 'cnn tennessee movie theater shooting suspect killed police http t di8elzswnr', 'rioting couple hours left class', 'crack path wiped morning beach run surface wounds left elbow right knee http t yaqrsximph', 'experts france begin examining airplane debris reunion island french air accident experts http t tagzbcxfj0 mlb', 'came kill indians fun video smirking remorseless pakistani killer shows boasting http t fpjlwoxklg', 'johnsontionne idk s burning', 'destroy house', 'police officer wounded suspect dead exchanging shots http t xxfk4khbiw', 'm friggin wreck destiel sucks read vine description https t mkx6ux4ozt', 'sterling scott red carpet fundraiser oso mudslide https t ma4ra7atql http t cg579wldne', 'libertarianluke m honest people want rampage let use hands feet casualties', 'http t 7xglah10zl feared killed pakistani air ambulance helicopter crash http t thmblaatzp', 'got electrocuted night work time life shit weird', 'older native australians believe oceans created urine angry god tried drown world', 'architect kanye west\x89ûªs volcano https t musbik7ejf', 'india shud evidence 2 pak share terrorists amp use attack share oth contries https t qiopbtiuvu', 'auth louis vuitton brown saumur 35 cross body shoulder bag monogram 7 23 419 3 read\x89û http t hcdiwe5flc http t zlvebeoavg', 'episode trunks annihilated freiza cleanest shit showed nigga mercy', 'roughdeal1 ante hudhud cyclone chandrababu valle ne ante ga', 'zhenghxn tried 11 eyes akame ga kill tokyo ghoul damn bloody dont dare watch', 'rayquazaerk christian terrorists sure t suicide bombing employed islamic groups', 'jackmulholland1 think marquis carlos amp charlie s finally dublin s sadly demolished', 'let people surf hi waimea bay s like beach inundated surfers https t czdw8oowa2', 'motorcyclist bicyclist injured denver collision broadway http t zl7ojdaj3u', 'maryland mansion killed 6 caused damaged plug christmas tree report says flames http t lkjfabqzb3', 'think going demolish drake s house ghostwriting shit know rihanna lives door', '1acd4900c1424d1 foxnews rioting burning buildings looting', 'forest fires amp dying salmon time 2 act deny climate change nightmares http t rbzomwgjee bcpoli canpoli vanpoli', 'http t ns1aggfnxz shoes asics gt ii super red 2 0 11 ronnie fieg kith red white 3m x gel grey volcano 2 http t od250zshfy', 'watch airport swallowed sandstorm minute http t wd9odwjj9l', 'tweetlikeitsseptember11th2001 buildings', 'california oil spill larger projected http t xwxbyhtuzc http t wzedxefblg', 'cartoon bears qave knowlddge forest fires toilet paper', 'gaabyx got purple activist thought drought', 'buffoonmike knew mo bite influenced shitty staff injuries acquisitions', 'toddstarnes enjoy impending landslide todd hehe', 'look grizzly peak right looks like beginning dystopian apocalypse movie', 'ignition knock detonation sensor senso standard ks100 http t 7o4lnfbe7k http t fvzsgjtbew', 'week responders dart members participating day intensive technical large animal http t tl93aod3er', 'lot 20 tom clancy military mystery novels paperback http t obix79ncxn tomclancy', 'drowning low self image quiz http t z8r6r3nbtb http t namffldh5h', 'm gonna fight taylor soon', 'wish victoria s secret m good', 'spot flood combo 53inch 300w curved cree led work light bar 4x4 offroad fog lamp re\x89û http t o097vsotxk http t i23xy7iejj', 'severe weather bulletin 5 typhoon \x89ûï hannaph\x89û\x9d soudelor tropical cyclone warning issued 5 00 pm 06 http t thhjjw51pe \x89û', 'ignition knock detonation sensor senso fits 01 06 bmw 325ci 2 5l l6 http t gbvdnczjou http t c211hise0r', '10 injured explosion chemical park western germany http t xbznu0qkvs', 'soul food sound bomb right', 'truth https t bejftygjil news bbc cnn islam truth god isis terrorism qu ...

# %%
print(type(y_train_list))
print(y_train_list)
# Out:
# <class 'pandas.core.series.Series'>
# 1186    0
# 4071    1
# 5461    1
# 5787    1
# 7445    0
#        ..
# 5226    0
# 5390    0
# 860     0
# 7603    1
# 7270    1
# Name: target, Length: 5329, dtype: int64

# %% [markdown]
# ## Feature Engieering via "CountVectorizer"
#
# - From List to Matrix via "CountVectorizer"
#
# - List shape: N_tweets x 1
# - Matrix shape: N_tweets x N_WordsInCorpus

# %%
train_vectorizer = CountVectorizer()
Xcv_train_matrix = train_vectorizer.fit_transform(X_train_list)
Xcv_test_matrix = train_vectorizer.transform(X_test_list)

print('Train matrix shape', Xcv_train_matrix.shape)
print('Test matrix shape', Xcv_test_matrix.shape)
# Out:
# Train matrix shape (5329, 16711)
# Test matrix shape (2284, 16711)

# %%
feature_names = train_vectorizer.get_feature_names()
#print(feature_names)
train_vectorizer.vocabulary_
# Out:
# {'ashes': 1698,
#  '2015': 276,
#  'australia': 1820,
#  'ûªs': 16682,
#  'collapse': 3475,
#  'trent': 14934,
#  'bridge': 2602,
#  'worst': 16118,
#  'history': 7013,
#  'england': 5146,
#  'bundled': 2725,
#  '60': 668,
#  'http': 7186,
#  't5trhjuau0': 14250,
#  'great': 6516,
#  'michigan': 9567,
#  'technique': 14397,
#  'camp': 2890,
#  'b1g': 1899,
#  'thanks': 14505,
#  'bmurph1019': 2428,
#  'hail': 6708,
#  'youtsey': 16475,
#  'termn8r13': 14449,
#  'goblue': 6406,
#  'wrestleon': 16152,
#  'oaskgki6qj': 10508,
#  'cnn': 3423,
#  'tennessee': 14435,
#  'movie': 9878,
#  'theater': 14517,
#  'shooting': 13254,
#  'suspect': 14160,
#  'killed': 8357,
#  'police': 11389,
#  'di8elzswnr': 4387,
#  'rioting': 12479,
#  'couple': 3743,
#  'hours': 7150,
#  'left': 8714,
#  'class': 3350,
#  'crack': 3778,
#  'path': 11031,
#  'wiped': 16001,
#  'morning': 9830,
#  'beach': 2108,
#  'run': 12708,
#  'surface': 14136,
#  'wounds': 16126,
#  'elbow': 5010,
#  'right': 12463,
#  'knee': 8418,
#  'yaqrsximph': 16376,
#  'experts': 5382,
#  'france': 5953,
#  'begin': 2153,
#  'examining': 5329,
#  'airplane': 1285,
#  'debris': 4147,
#  'reunion': 12392,
#  'island': 7770,
#  'french': 5992,
#  'air': 1280,
#  'accident': 1081,
#  'tagzbcxfj0': 14272,
#  'mlb': 9721,
#  'came': 2880,
#  'kill': 8356,
#  'indians': 7540,
#  'fun': 6065,
#  'video': 15559,
#  'smirking': 13504,
#  'remorseless': 12267,
#  'pakistani': 10938,
#  'killer': 8358,
#  'shows': 13282,
#  'boasting': 2441,
#  'fpjlwoxklg': 5934,
#  'johnsontionne': 8047,
#  'idk': 7369,
#  'burning': 2740,
#  'destroy': 4322,
#  'house': 7151,
#  'officer': 10580,
#  'wounded': 16125,
#  'dead': 4124,
#  'exchanging': 5337,
#  'shots': 13266,
#  'xxfk4khbiw': 16323,
#  'friggin': 6015,
#  'wreck': 16149,
#  'destiel': 4316,
#  'sucks': 14056,
#  'read': 12099,
#  'vine': 15578,
#  'description': 4297,
#  'https': 7187,
#  'mkx6ux4ozt': 9719,
#  'sterling': 13893,
#  'scott': 12966,
#  'red': 12170,
#  'carpet': 2985,
#  'fundraiser': 6068,
#  'oso': 10798,
#  'mudslide': 9932,
#  'ma4ra7atql': 9182,
#  'cg579wldne': 3115,
#  'libertarianluke': 8799,
#  'honest': 7093,
#  'people': 11121,
#  'want': 15747,
#  'rampage': 12016,
#  'let': 8764,
#  'use': 15368,
#  'hands': 6743,
#  'feet': 5607,
#  'casualties': 3015,
#  '7xglah10zl': 823,
#  'feared': 5585,
#  'ambulance': 1412,
#  'helicopter': 6904,
#  'crash': 3793,
#  'thmblaatzp': 14596,
#  'got': 6456,
#  'electrocuted': 5022,
#  'night': 10250,
#  'work': 16091,
#  'time': 14676,
#  'life': 8811,
#  'shit': 13239,
#  'weird': 15867,
#  'older': 10651,
#  'native': 10085,
#  'australians': 1822,
#  'believe': 2173,
#  'oceans': 10543,
#  'created': 3812,
#  'urine': 15349,
#  'angry': 1474,
#  'god': 6408,
#  'tried': 14952,
#  'drown': 4745,
#  'world': 16101,
#  'architect': 1614,
#  'kanye': 8220,
#  'west': 15885,
#  'volcano': 15644,
#  'musbik7ejf': 9961,
#  'india': 7534,
#  'shud': 13288,
#  'evidence': 5315,
#  'pak': 10936,
#  'share': 13188,
#  'terrorists': 14460,
#  'amp': 1431,
#  'attack': 1770,
#  'oth': 10805,
#  'contries': 3662,
#  'qiopbtiuvu': 11839,
#  'auth': 1824,
#  'louis': 9040,
#  'vuitton': 15677,
#  'brown': 2651,
#  'saumur': 12889,
#  '35': 420,
#  'cross': 3856,
#  'body': 2449,
#  'shoulder': 13267,
#  'bag': 1952,
#  'monogram': 9793,
#  '23': 301,
#  '419': 509,
#  'hcdiwe5flc': 6833,
#  'zlvebeoavg': 16612,
#  'episode': 5203,
#  'trunks': 15000,
#  'annihilated': 1491,
#  'freiza': 5990,
#  'cleanest': 3357,
#  'showed': 13278,
#  'nigga': 10247,
#  'mercy': 9497,
#  'roughdeal1': 12632,
#  'ante': 1508,
#  'hudhud': 7192,
#  'cyclone': 3972,
#  'chandrababu': 3144,
#  'valle': 15447,
#  'ne': 10132,
#  'ga': 6140,
#  'zhenghxn': 16587,
#  '11': 109,
#  'eyes': 5431,
#  'akame': 1300,
#  'tokyo': 14756,
#  'ghoul': 6303,
#  'damn': 4031,
#  'bloody': 2395,
#  'dont': 4632,
#  'dare': 4069,
#  'watch': 15785,
#  'rayquazaerk': 12066,
#  'christian': 3271,
#  'sure': 14131,
#  'suicide': 14069,
#  'bombing': 2463,
#  'employed': 5097,
#  'islamic': 7768,
#  'groups': 6562,
#  'jackmulholland1': 7859,
#  'think': 14581,
#  'marquis': 9323,
#  'carlos': 2974,
#  'charlie': 3168,
#  'finally': 5687,
#  'dublin': 4777,
#  'sadly': 12783,
#  'demolished': 4243,
#  'surf': 14135,
#  'hi': 6959,
#  'waimea': 15717,
#  'bay': 2070,
#  'like': 8833,
#  'inundated': 7690,
#  'surfers': 14137,
#  'czdw8oowa2': 3983,
#  'motorcyclist': 9858,
#  'bicyclist': 2255,
#  'injured': 7596,
#  'denver': 4266,
#  'collision': 3489,
#  'broadway': 2633,
#  'zl7ojdaj3u': 16608,
#  'maryland': 9334,
#  'mansion': 9276,
#  'caused': 3039,
#  'damaged': 4022,
#  'plug': 11345,
#  'christmas': 3277,
#  'tree': 14920,
#  'report': 12303,
#  'says': 12907,
#  'flames': 5757,
#  'lkjfabqzb3': 8921,
#  'going': 6416,
#  'demolish': 4242,
#  'drake': 4683,
#  'ghostwriting': 6302,
#  'know': 8435,
#  'rihanna': 12468,
#  'lives': 8906,
#  'door': 4636,
#  '1acd4900c1424d1': 214,
#  'foxnews': 5926,
#  'buildings': 2707,
#  'looting': 9010,
#  'forest': 5883,
#  'fires': 5719,
#  'dying': 4842,
#  'salmon': 12816,
#  'act': 1117,
#  'deny': 4267,
#  'climate': 3379,
#  'change': 3145,
#  'nightmares': 10253,
#  'rbzomwgjee': 12078,
#  'bcpoli': 2098,
#  'canpoli': 2924,
#  'vanpoli': 15463,
#  'ns1aggfnxz': 10401,
#  'shoes': 13249,
#  'asics': 1709,
#  'gt': 6584,
#  'ii': 7410,
#  'super': 14107,
#  'ronnie': 12603,
#  'fieg': 5657,
#  'kith': 8391,
#  'white': 15929,
#  '3m': 469,
#  'gel': 6235,
#  'grey': 6538,
#  'od250zshfy': 10547,
#  'airport': 1287,
#  'swallowed': 14171,
#  'sandstorm': 12850,
#  'minute': 9655,
#  'wd9odwjj9l': 15825,
#  'tweetlikeitsseptember11th2001': 15079,
#  'california': 2865,
#  'oil': 10622,
#  'spill': 13708,
#  'larger': 8613,
#  'projected': 11620,
#  'xwxbyhtuzc': 16322,
#  'wzedxefblg': 16217,
#  'cartoon': 2995,
#  'bears': 2116,
#  'qave': 11811,
#  'knowlddge': 8437,
#  'toilet': 14753,
#  'paper': 10972,
#  'gaabyx': 6142,
#  'purple': 11749,
#  'activist': 1129,
#  'thought': 14608,
#  'drought': 4740,
#  'buffoonmike': 2702,
#  'knew': 8422,
#  'mo': 9737,
#  'bite': 2313,
#  'influenced': 7580,
#  'shitty': 13242,
#  'staff': 13807,
#  'injuries': 7598,
#  'acquisitions': 1113,
#  'toddstarnes': 14746,
#  'enjoy': 5152,
#  'impending': 7477,
#  'landslide': 8594,
#  'todd': 14744,
#  'hehe': 6892,
#  'look': 8995,
#  'grizzly': 6550,
#  'peak': 11095,
#  'looks': 8999,
#  'beginning': 2155,
#  'dystopian': 4847,
#  'apocalypse': 1552,
#  'ignition': 7396,
#  'knock': 8430,
#  'detonation': 4339,
#  'sensor': 13092,
#  'senso': 13091,
#  'standard': 13819,
#  'ks100': 8483,
#  '7o4lnfbe7k': 815,
#  'fvzsgjtbew': 6094,
#  'week': 15858,
#  'responders': 12352,
#  'dart': 4080,
#  'members': 9475,
#  'participating': 11009,
#  'day': 4104,
#  'intensive': 7659,
#  'technical': 14395,
#  'large': 8612,
#  'animal': 1476,
#  'tl93aod3er': 14714,
#  'lot': 9033,
#  '20': 263,
#  'tom': 14761,
#  'clancy': 3346,
#  'military': 9609,
#  'mystery': 10012,
#  'novels': 10381,
#  'paperback': 10973,
#  'obix79ncxn': 10514,
#  'tomclancy': 14765,
#  'drowning': 4747,
#  'low': 9052,
#  'self': 13067,
#  'image': 7454,
#  'quiz': 11905,
#  'z8r6r3nbtb': 16543,
#  'namffldh5h': 10057,
#  'gonna': 6427,
#  'fight': 5665,
#  'taylor': 14343,
#  'soon': 13609,
#  'wish': 16012,
#  'victoria': 15551,
#  'secret': 13034,
#  'good': 6428,
#  'spot': 13738,
#  'flood': 5796,
#  'combo': 3508,
#  '53inch': 606,
#  '300w': 398,
#  'curved': 3939,
#  'cree': 3822,
#  'led': 8705,
#  'light': 8822,
#  'bar': 2004,
#  '4x4': 579,
#  'offroad': 10594,
#  'fog': 5833,
#  'lamp': 8578,
#  're': 12087,
#  'o097vsotxk': 10481,
#  'i23xy7iejj': 7293,
#  'severe': 13139,
#  'weather': 15843,
#  'bulletin': 2713,
#  'typhoon': 15116,
#  'ûï': 16685,
#  'hannaph': 6751,
#  'soudelor': 13627,
#  'tropical': 14976,
#  'warning': 15761,
#  'issued': 7780,
#  '00': 0,
#  'pm': 11353,
#  '06': 19,
#  'thhjjw51pe': 14577,
#  'fits': 5731,
#  '01': 6,
#  'bmw': 2429,
#  '325ci': 413,
#  '5l': 639,
#  'l6': 8541,
#  'gbvdnczjou': 6221,
#  'c211hise0r': 2805,
#  '10': 81,
#  'explosion': 5398,
#  'chemical': 3198,
#  'park': 10995,
#  'western': 15886,
#  'germany': 6272,
#  'xbznu0qkvs': 16247,
#  'soul': 13628,
#  'food': 5853,
#  'sound': 13632,
#  'bomb': 2459,
#  'truth': 15004,
#  'bejftygjil': 2168,
#  'news': 10192,
#  'bbc': 2077,
#  'islam': 7766,
#  'isis': 7764,
#  'terrorism': 14458,
#  'quran': 11914,
#  'lies': 8810,
#  'jlczidz7vu': 8010,
#  'if': 7380,
#  'lost': 9032,
#  'sinking': 13359,
#  'stone': 13927,
#  'carry': 2988,
#  'onå': 10701,
#  'mylittlepwnies3': 10008,
#  'early': 4883,
#  'anathemazhiv': 1446,
#  'tonysandos': 14779,
#  'lebanon': 8702,
#  '80s': 836,
#  'iran': 7735,
#  'hostage': 7137,
#  'crisis': 3845,
#  'libya': 8805,
#  'pan': 10952,
#  'pulls': 11723,
#  'gun': 6612,
#  'man': 9259,
#  'apparent': 1563,
#  'provocation': 11675,
#  'lhw4vtbhzg': 8794,
#  'dailykos': 4010,
#  'train': 14876,
#  'derailment': 4286,
#  'patna': 11039,
#  'casualty': 3016,
#  'far': 5522,
#  'indian': 7537,
#  'express': 5406,
#  'yh5vetm0yz': 16422,
#  '17wgug8z0m': 181,
#  'dream': 4698,
#  'magic': 9213,
#  'linden': 8854,
#  'method': 9523,
#  'lite': 8883,
#  'version': 15518,
#  'anxiety': 1523,
#  'panic': 10961,
#  'cure': 3929,
#  'program': 11611,
#  '073izwx0lb': 23,
#  'lind': 8852,
#  'okmlagvkjv': 10642,
#  '18': 182,
#  'bovines': 2513,
#  'rescued': 12323,
#  'smugglersåênabbed': 13516,
#  'e7fn5g5ruu': 4869,
#  'wwp': 16201,
#  'serving': 13122,
#  '75k': 777,
#  'veterans': 15524,
#  '52k': 602,
#  'oif': 10621,
#  'oef': 10558,
#  'vets': 15525,
#  'physical': 11215,
#  'invisible': 7704,
#  'ones': 10682,
#  'shhlv4dplz': 13220,
#  'client': 3375,
#  'learned': 8694,
#  'economics': 4927,
#  'south': 13642,
#  'dakota': 4014,
#  'dust': 4810,
#  'storm': 13942,
#  'years': 16396,
#  'college': 3483,
#  'hubert': 7191,
#  'humphrey': 7225,
#  'cramer': 3786,
#  'iger': 7388,
#  'words': 16090,
#  'wrecked': 16151,
#  'disney': 4495,
#  'stock': 13918,
#  'sf5jdnvdw9': 13152,
#  'til': 14671,
#  'cnbc': 3419,
#  'marc': 9286,
#  'holl': 7059,
#  'nennicook': 10163,
#  'aitchkaycee': 1292,
#  'vixstuart': 15615,
#  'benjbeckwith': 2199,
#  'pretty': 11552,
#  'disaster': 4466,
#  'gbbo': 6214,
#  'need': 10145,
#  'arcade': 1612,
#  'shooter': 13253,
#  'fix': 5735,
#  'cte': 3897,
#  'running': 12714,
#  'obliteration': 10523,
#  'buy': 2774,
#  'cod': 3448,
#  'title': 14701,
#  'weren': 15881,
#  'overpriced': 10850,
#  'steam': 13878,
#  'firepower': 5718,
#  'lab': 8553,
#  'electronic': 5023,
#  'resource': 12344,
#  'automation': 1835,
#  'infectious': 7568,
#  'diseases': 4485,
#  'bioterrorism': 2296,
#  'kvpbybglsr': 8510,
#  'graysondolan': 6512,
#  'kendall': 8287,
#  'jenner': 7954,
#  'nick': 10233,
#  'jonas': 8059,
#  'dating': 4088,
#  'literally': 8884,
#  'explode': 5390,
#  'pfvzvpxqgr': 11176,
#  'tell': 14418,
#  'mom': 9776,
#  'bring': 2615,
#  'hold': 7049,
#  'cat': 3017,
#  'rt': 12677,
#  'startelegram': 13845,
#  'homeless': 7078,
#  'vulnerable': 15680,
#  'north': 10340,
#  'texas': 14474,
#  'heat': 6877,
#  'wave': 15798,
#  'k9airfq3ql': 8189,
#  'jdbtlymehy': 7938,
#  'nuclear': 10414,
#  'solar': 13573,
#  'power': 11460,
#  'japanese': 7901,
#  'fukushima': 6061,
#  'reactor': 12096,
#  'energy': 5136,
#  'japan': 7900,
#  'temperature': 14428,
#  'fuel': 6055,
#  'pool': 11404,
#  'ys3nmwwyvc': 16497,
#  'alpotnb7q3': 1387,
#  'taken': 14282,
#  'local': 8952,
#  'wlmsq3mtho': 16039,
#  'esteemed': 5260,
#  'journalist': 8078,
#  'recalls': 12140,
#  'tragic': 14872,
#  'effects': 4973,
#  'unaddressed': 15224,
#  'childhood': 3223,
#  'trauma': 14902,
#  'keithboykin': 8276,
#  'randallpinkston': 12020,
#  'pozarmy': 11465,
#  'gxq1auzb18': 6655,
#  'feel': 5599,
#  'panicking': 10962,
#  'results': 12374,
#  'alarmingly': 1322,
#  'calm': 2871,
#  'thunder': 14642,
#  'lightning': 8828,
#  'possible': 11432,
#  'pinpoint': 11250,
#  'foothill': 5867,
#  'forecast': 5876,
#  'ctijdpxabk': 3898,
#  '40': 495,
#  'displaced': 4506,
#  'ocean': 10542,
#  'township': 14839,
#  'apartment': 1540,
#  'newyork': 10203,
#  'uelz59wvom': 15179,
#  'freddiedeboer': 5968,
#  'thucydiplease': 14640,
#  'rise': 12489,
#  'coates': 3440,
#  'charleston': 3166,
#  'massacre': 9343,
#  'walter': 15741,
#  'black': 2336,
#  'twitter': 15091,
#  'broadly': 2632,
#  'mathew': 9363,
#  'z3ke': 16535,
#  'sk1': 13395,
#  'saladinahmed': 12807,
#  'died': 4409,
#  'horrible': 7124,
#  'deaths': 4142,
#  'trapped': 14900,
#  'ships': 13234,
#  'risk': 12492,
#  'destruction': 4328,
#  'fine': 5693,
#  'reality': 12115,
#  'training': 14878,
#  'falls': 5495,
#  'elevated': 5033,
#  'tracks': 14859,
#  'windstorm': 15983,
#  'jiomnrcygt': 7999,
#  'paramedic': 10983,
#  'ems': 5102,
#  'fears': 5587,
#  'missing': 9681,
#  'migrants': 9594,
#  'med': 9435,
#  'rescuers': 12324,
#  'search': 13014,
#  'survivors': 14155,
#  'boat': 2442,
#  'carrying': 2990,
#  '6ds67xai5e': 713,
#  'derailed': 4285,
#  'benchmark': 2187,
#  'cool': 3674,
#  'paths': 11035,
#  'wonder': 16074,
#  'leaks': 8691,
#  'jobs': 8029,
#  'given': 6340,
#  'resque': 12358,
#  'new': 10181,
#  'ladies': 8563,
#  'tote': 14818,
#  'handbag': 6736,
#  'women': 16069,
#  'faux': 5552,
#  'leather': 8698,
#  'fashion': 5536,
#  'purse': 11754,
#  'y87gi3brlv': 16353,
#  '1zbhvdcxzs': 262,
#  'raishimi33': 12006,
#  'sounds': 13636,
#  'plan': 11301,
#  'little': 8889,
#  'applaud': 1569,
#  'invading': 7693,
#  'iraq': 7740,
#  'catastrophic': 3022,
#  'mistake': 9689,
#  'diplomacy': 4440,
#  'needs': 10149,
#  'replace': 12298,
#  'constant': 3635,
#  'threat': 14616,
#  'war': 15751,
#  'israel': 7777,
#  'yqjpn3quux': 16487,
#  'related': 12231,
#  'threatens': 14619,
#  'europe': 5286,
#  'wk6b5z803o': 16034,
#  'marynmck': 9335,
#  'adorable': 1173,
#  'hope': 7108,
#  'won': 16073,
#  'noticed': 10366,
#  'devastation': 4347,
#  'coming': 3520,
#  'target': 14314,
#  'starbucks': 13834,
#  'closed': 3393,
#  'momneedscoffee': 9780,
#  'asap': 1687,
#  'iwontmakeit': 7813,
#  'redskins': 12182,
#  'wr': 16142,
#  'roberts': 12544,
#  'belly': 2180,
#  'bombed': 2460,
#  'teamstream': 14386,
#  'gbcvvevdty': 6215,
#  'allah': 1359,
#  'describes': 4295,
#  'piling': 11242,
#  'wealth': 15836,
#  'thinking': 14582,
#  'forever': 5884,
#  'hellfire': 6908,
#  'surah': 14130,
#  'humaza': 7216,
#  'reflect': 12194,
#  'loved': 9042,
#  'way': 15802,
#  'book': 2474,
#  'written': 16163,
#  'include': 7514,
#  'vantage': 15464,
#  'points': 11380,
#  'detkenlang': 4336,
#  'kindle': 8370,
#  'kcrnmjkj73': 8260,
#  'heartdisease': 6870,
#  'service': 13119,
#  'spending': 13699,
#  'half': 6720,
#  'budget': 2696,
#  'kzfigkeeva': 8527,
#  'forget': 5887,
#  'tragedy': 14871,
#  'gajtugaui7': 6155,
#  'liked': 8834,
#  'youtube': 16477,
#  'itsjustinstuart': 7793,
#  'mnkaji2q1n': 9734,
#  'range': 12027,
#  'mayhem': 9385,
#  'hungerarticles': 7230,
#  'nepal': 10166,
#  'rebuilding': 12135,
#  'livelihoods': 8899,
#  'quake': 11874,
#  'lrouwjmbix': 9066,
#  'suspected': 14161,
#  'serial': 13113,
#  'arsonist': 1668,
#  'arrested': 1658,
#  'calif': 2864,
#  'pzotpdgaki': 11788,
#  'chubbysquirrel': 3283,
#  'hurricane': 7247,
#  'surge': 14138,
#  'true': 14994,
#  '33333': 416,
#  '9vw0uqqi1y': 986,
#  'marvel': 9332,
#  'vs': 15669,
#  'dc': 4110,
#  'avengers': 1846,
#  'battle': 2064,
#  'rockbottomradfm': 12553,
#  'challenges': 3133,
#  'tough': 14824,
#  'rescuing': 12325,
#  'goes': 6414,
#  'engine': 5141,
#  'tyjxrfd3st': 15111,
#  'regular': 12219,
#  'coffees': 3456,
#  'rockstar': 12561,
#  'coffee': 3455,
#  'today': 14739,
#  'tired': 14695,
#  'butt': 2769,
#  'extraordinaire': 5421,
#  'nws': 10449,
#  'wth': 16178,
#  'rotating': 12627,
#  'huge': 7201,
#  'massive': 9346,
#  'violent': 15587,
#  'tornado': 14798,
#  'j3di85ist5': 7834,
#  'swb1192': 14179,
#  'nda': 10124,
#  'damage': 4021,
#  'ability': 1045,
#  'offer': 10576,
#  'services': 13120,
#  'future': 6086,
#  'prolly': 11624,
#  'ameenshaikh3': 1416,
#  'sir': 13362,
#  'wanted': 15748,
#  'point': 11378,
#  'sureshpprabhu': 14133,
#  'said': 12796,
#  'lying': 9128,
#  'sinkhole': 13358,
#  'swallows': 14172,
#  'brooklyn': 2644,
#  'intersection': 7677,
#  'ûò': 16705,
#  '1ybe5mgzl4': 260,
#  '7zog3dpdu9': 828,
#  'jacksonville': 7862,
#  'family': 5503,
#  'bands': 1985,
#  'memorial': 9480,
#  'planned': 11306,
#  'tilgurkv7z': 14672,
#  '405': 500,
#  'southbound': 13644,
#  'coal': 3435,
#  'creek': 3823,
#  'pkwy': 11292,
#  'blocking': 2388,
#  'center': 3094,
#  'lane': 8596,
#  'im': 7449,
#  'feeling': 5601,
#  'attacked': 1771,
#  '91jvycxxvi': 908,
#  'felt': 5615,
#  'namekians': 10055,
#  'played': 11318,
#  'planet': 11304,
#  'destroyed': 4324,
#  'acc': 1075,
#  'study': 14016,
#  'conducted': 3602,
#  'skims': 13410,
#  'morethan': 9823,
#  '50': 589,
#  'population': 11413,
#  'kashmir': 8232,
#  'suffer': 14060,
#  'psychiatric': 11693,
#  'disorders': 4499,
#  'saf9mosksn': 12784,
#  'kashmirconflict': 8233,
#  'ideas': 7358,
#  'flattened': 5767,
#  'qfrawln4ba': 11828,
#  'eating': 4910,
#  'takis': 14285,
#  'rubbing': 12686,
#  'bleeding': 2366,
#  'tears': 14391,
#  'link': 8860,
#  'reddit': 12175,
#  'content': 3646,
#  'policy': 11391,
#  'effect': 4970,
#  'subreddits': 14044,
#  'banned': 1997,
#  'quarantined': 11880,
#  'cd2ng2awql': 3066,
#  'ig': 7386,
#  '2wbivkzjip': 386,
#  'hailing': 6710,
#  'abstorm': 1061,
#  'yyc': 16523,
#  'hailstorm': 6711,
#  'haildamage': 6709,
#  'yycweather': 16527,
#  'calgary': 2859,
#  'captureyyc': 2948,
#  'alberta': 1329,
#  'sto': 13916,
#  'britney': 2623,
#  'spears': 13676,
#  'vegas': 15495,
#  'missed': 9679,
#  'can': 2904,
#  'ûªt': 16683,
#  'wait': 15719,
#  'tonight': 14772,
#  'pieceofme': 11230,
#  'catastrophe': 3021,
#  '4mjyw7p7cf': 565,
#  'disco': 4472,
#  'best': 2214,
#  'song': 13596,
#  'gospel': 6454,
#  'acoustic': 1111,
#  'vcq2icptki': 15485,
#  'tune': 15040,
#  'a8jz5a26wi': 1009,
#  'theatershooting': 14518,
#  'defendant': 4190,
#  'mass': 9342,
#  'murderer': 9956,
#  'chose': 3257,
#  'testify': 14468,
#  'final': 5683,
#  'phase': 11189,
#  'subject': 14039,
#  'exam': 5327,
#  'jury': 8141,
#  'questions': 11898,
#  'brooke': 2643,
#  'face': 5457,
#  'timed': 14680,
#  'concert': 3586,
#  'screamed': 12980,
#  'minutes': 9656,
#  'straight': 13951,
#  'yup': 16510,
#  'hasn': 6799,
#  'sunk': 14098,
#  'ii2spvp89b': 7411,
#  'rodpt33xfm': 12567,
#  'eversafe': 5307,
#  'emergency': 5073,
#  'auto': 1831,
#  'kit': 8388,
#  'unsafe': 15294,
#  'hazardous': 6823,
#  'rush': 12720,
#  'hour': 7149,
#  'gridlock': 6542,
#  'jumper': 8132,
#  'ca': 2819,
#  '0bvk5tub4j': 32,
#  'demoness': 4247,
#  'voice': 15640,
#  'angel': 1464,
#  'siren': 13364,
#  'beckoning': 2133,
#  'void': 15642,
#  'this': 14588,
#  'nps3xpbkaq': 10389,
#  'aftershock': 1233,
#  'delo': 4224,
#  'speaking': 13674,
#  'scuf': 12995,
#  'xb1': 16244,
#  'end': 5121,
#  'getting': 6279,
#  'ps': 11679,
#  'anti': 1513,
#  'rear': 12123,
#  'technology': 14399,
#  'vpvj5hrc1i': 15664,
#  'techesback': 14394,
#  'tech': 14393,
#  'proud': 11667,
#  'joegoodmanjr': 8033,
#  'watching': 15788,
#  'copalibertadores': 3684,
#  'argentinean': 1627,
#  'pandemonium': 10958,
#  '8tygo0kizz': 890,
#  'causing': 3041,
#  'evacuations': 5294,
#  'downtown': 4662,
#  'hinton': 6999,
#  'mtmkimwiyy': 9923,
#  'research': 12326,
#  'collective': 3481,
#  'memory': 9482,
#  '1st': 248,
#  'rule': 12702,
#  'writing': 16160,
#  'diverse': 4527,
#  'touch': 14821,
#  'group': 6560,
#  'phfoeozyps': 11191,
#  'jax': 7920,
#  'issues': 7781,
#  'outlook': 10831,
#  'hwo': 7266,
#  'fucoqhclad': 6053,
#  'chowtaxis': 3261,
#  'newport': 10191,
#  'big': 2261,
#  'pick': 11218,
#  'jackie': 7858,
#  'bristol': 2619,
#  'temple': 14430,
#  ...}

# %%
sparse_vectors = Xcv_train_matrix.toarray()

Tweet_nbr =0;
Word_nbr =1820;  #e.g., 1820 = 'australia'

sparse_vectors[0,1820]  # we get ones (or twos) at the right place
# Out:
# 2

# %% [markdown]
# ## Features: CountVectorizer, Classifier: Logistic Regression

# %%
model_CV_LR =LogisticRegression().fit(Xcv_train_matrix, y_train_list)

CV_LR_score_train =model_CV_LR.score(Xcv_train_matrix, y_train_list)
#model_LR.predict(Xcv_test_matrix)
CV_LR_score_test =model_CV_LR.score(Xcv_test_matrix, y_test_list)

print('score for test data:', CV_LR_score_test)
print(classification_report(y_test_list, model_CV_LR.predict(Xcv_test_matrix)) )
# Out:
# score for test data: 0.7981611208406305
#               precision    recall  f1-score   support
#
#            0       0.80      0.87      0.83      1318
#            1       0.80      0.70      0.75       966
#
#     accuracy                           0.80      2284
#    macro avg       0.80      0.79      0.79      2284
# weighted avg       0.80      0.80      0.80      2284

# %% [markdown]
# ## Features: TFIDF,  Classifier: Logistic Regression

# %%
train_vectorizer = TfidfVectorizer()

# %%
Xtf_train_matrix = train_vectorizer.fit_transform(X_train_list)
Xtf_test_matrix = train_vectorizer.transform(X_test_list)

print('Train matrix shape', Xtf_train_matrix.shape)
print('Test matrix shape', Xtf_test_matrix.shape)
# Out:
# Train matrix shape (5329, 16711)
# Test matrix shape (2284, 16711)

# %%
Xtf_train_matrix[0,1820]

Xtf_train_matrix[0,276]
# Out:
# 0.19644613494912055

# %%
feature_names = train_vectorizer.get_feature_names()
## print(feature_names)
train_vectorizer.vocabulary_
# Out:
# {'ashes': 1698,
#  '2015': 276,
#  'australia': 1820,
#  'ûªs': 16682,
#  'collapse': 3475,
#  'trent': 14934,
#  'bridge': 2602,
#  'worst': 16118,
#  'history': 7013,
#  'england': 5146,
#  'bundled': 2725,
#  '60': 668,
#  'http': 7186,
#  't5trhjuau0': 14250,
#  'great': 6516,
#  'michigan': 9567,
#  'technique': 14397,
#  'camp': 2890,
#  'b1g': 1899,
#  'thanks': 14505,
#  'bmurph1019': 2428,
#  'hail': 6708,
#  'youtsey': 16475,
#  'termn8r13': 14449,
#  'goblue': 6406,
#  'wrestleon': 16152,
#  'oaskgki6qj': 10508,
#  'cnn': 3423,
#  'tennessee': 14435,
#  'movie': 9878,
#  'theater': 14517,
#  'shooting': 13254,
#  'suspect': 14160,
#  'killed': 8357,
#  'police': 11389,
#  'di8elzswnr': 4387,
#  'rioting': 12479,
#  'couple': 3743,
#  'hours': 7150,
#  'left': 8714,
#  'class': 3350,
#  'crack': 3778,
#  'path': 11031,
#  'wiped': 16001,
#  'morning': 9830,
#  'beach': 2108,
#  'run': 12708,
#  'surface': 14136,
#  'wounds': 16126,
#  'elbow': 5010,
#  'right': 12463,
#  'knee': 8418,
#  'yaqrsximph': 16376,
#  'experts': 5382,
#  'france': 5953,
#  'begin': 2153,
#  'examining': 5329,
#  'airplane': 1285,
#  'debris': 4147,
#  'reunion': 12392,
#  'island': 7770,
#  'french': 5992,
#  'air': 1280,
#  'accident': 1081,
#  'tagzbcxfj0': 14272,
#  'mlb': 9721,
#  'came': 2880,
#  'kill': 8356,
#  'indians': 7540,
#  'fun': 6065,
#  'video': 15559,
#  'smirking': 13504,
#  'remorseless': 12267,
#  'pakistani': 10938,
#  'killer': 8358,
#  'shows': 13282,
#  'boasting': 2441,
#  'fpjlwoxklg': 5934,
#  'johnsontionne': 8047,
#  'idk': 7369,
#  'burning': 2740,
#  'destroy': 4322,
#  'house': 7151,
#  'officer': 10580,
#  'wounded': 16125,
#  'dead': 4124,
#  'exchanging': 5337,
#  'shots': 13266,
#  'xxfk4khbiw': 16323,
#  'friggin': 6015,
#  'wreck': 16149,
#  'destiel': 4316,
#  'sucks': 14056,
#  'read': 12099,
#  'vine': 15578,
#  'description': 4297,
#  'https': 7187,
#  'mkx6ux4ozt': 9719,
#  'sterling': 13893,
#  'scott': 12966,
#  'red': 12170,
#  'carpet': 2985,
#  'fundraiser': 6068,
#  'oso': 10798,
#  'mudslide': 9932,
#  'ma4ra7atql': 9182,
#  'cg579wldne': 3115,
#  'libertarianluke': 8799,
#  'honest': 7093,
#  'people': 11121,
#  'want': 15747,
#  'rampage': 12016,
#  'let': 8764,
#  'use': 15368,
#  'hands': 6743,
#  'feet': 5607,
#  'casualties': 3015,
#  '7xglah10zl': 823,
#  'feared': 5585,
#  'ambulance': 1412,
#  'helicopter': 6904,
#  'crash': 3793,
#  'thmblaatzp': 14596,
#  'got': 6456,
#  'electrocuted': 5022,
#  'night': 10250,
#  'work': 16091,
#  'time': 14676,
#  'life': 8811,
#  'shit': 13239,
#  'weird': 15867,
#  'older': 10651,
#  'native': 10085,
#  'australians': 1822,
#  'believe': 2173,
#  'oceans': 10543,
#  'created': 3812,
#  'urine': 15349,
#  'angry': 1474,
#  'god': 6408,
#  'tried': 14952,
#  'drown': 4745,
#  'world': 16101,
#  'architect': 1614,
#  'kanye': 8220,
#  'west': 15885,
#  'volcano': 15644,
#  'musbik7ejf': 9961,
#  'india': 7534,
#  'shud': 13288,
#  'evidence': 5315,
#  'pak': 10936,
#  'share': 13188,
#  'terrorists': 14460,
#  'amp': 1431,
#  'attack': 1770,
#  'oth': 10805,
#  'contries': 3662,
#  'qiopbtiuvu': 11839,
#  'auth': 1824,
#  'louis': 9040,
#  'vuitton': 15677,
#  'brown': 2651,
#  'saumur': 12889,
#  '35': 420,
#  'cross': 3856,
#  'body': 2449,
#  'shoulder': 13267,
#  'bag': 1952,
#  'monogram': 9793,
#  '23': 301,
#  '419': 509,
#  'hcdiwe5flc': 6833,
#  'zlvebeoavg': 16612,
#  'episode': 5203,
#  'trunks': 15000,
#  'annihilated': 1491,
#  'freiza': 5990,
#  'cleanest': 3357,
#  'showed': 13278,
#  'nigga': 10247,
#  'mercy': 9497,
#  'roughdeal1': 12632,
#  'ante': 1508,
#  'hudhud': 7192,
#  'cyclone': 3972,
#  'chandrababu': 3144,
#  'valle': 15447,
#  'ne': 10132,
#  'ga': 6140,
#  'zhenghxn': 16587,
#  '11': 109,
#  'eyes': 5431,
#  'akame': 1300,
#  'tokyo': 14756,
#  'ghoul': 6303,
#  'damn': 4031,
#  'bloody': 2395,
#  'dont': 4632,
#  'dare': 4069,
#  'watch': 15785,
#  'rayquazaerk': 12066,
#  'christian': 3271,
#  'sure': 14131,
#  'suicide': 14069,
#  'bombing': 2463,
#  'employed': 5097,
#  'islamic': 7768,
#  'groups': 6562,
#  'jackmulholland1': 7859,
#  'think': 14581,
#  'marquis': 9323,
#  'carlos': 2974,
#  'charlie': 3168,
#  'finally': 5687,
#  'dublin': 4777,
#  'sadly': 12783,
#  'demolished': 4243,
#  'surf': 14135,
#  'hi': 6959,
#  'waimea': 15717,
#  'bay': 2070,
#  'like': 8833,
#  'inundated': 7690,
#  'surfers': 14137,
#  'czdw8oowa2': 3983,
#  'motorcyclist': 9858,
#  'bicyclist': 2255,
#  'injured': 7596,
#  'denver': 4266,
#  'collision': 3489,
#  'broadway': 2633,
#  'zl7ojdaj3u': 16608,
#  'maryland': 9334,
#  'mansion': 9276,
#  'caused': 3039,
#  'damaged': 4022,
#  'plug': 11345,
#  'christmas': 3277,
#  'tree': 14920,
#  'report': 12303,
#  'says': 12907,
#  'flames': 5757,
#  'lkjfabqzb3': 8921,
#  'going': 6416,
#  'demolish': 4242,
#  'drake': 4683,
#  'ghostwriting': 6302,
#  'know': 8435,
#  'rihanna': 12468,
#  'lives': 8906,
#  'door': 4636,
#  '1acd4900c1424d1': 214,
#  'foxnews': 5926,
#  'buildings': 2707,
#  'looting': 9010,
#  'forest': 5883,
#  'fires': 5719,
#  'dying': 4842,
#  'salmon': 12816,
#  'act': 1117,
#  'deny': 4267,
#  'climate': 3379,
#  'change': 3145,
#  'nightmares': 10253,
#  'rbzomwgjee': 12078,
#  'bcpoli': 2098,
#  'canpoli': 2924,
#  'vanpoli': 15463,
#  'ns1aggfnxz': 10401,
#  'shoes': 13249,
#  'asics': 1709,
#  'gt': 6584,
#  'ii': 7410,
#  'super': 14107,
#  'ronnie': 12603,
#  'fieg': 5657,
#  'kith': 8391,
#  'white': 15929,
#  '3m': 469,
#  'gel': 6235,
#  'grey': 6538,
#  'od250zshfy': 10547,
#  'airport': 1287,
#  'swallowed': 14171,
#  'sandstorm': 12850,
#  'minute': 9655,
#  'wd9odwjj9l': 15825,
#  'tweetlikeitsseptember11th2001': 15079,
#  'california': 2865,
#  'oil': 10622,
#  'spill': 13708,
#  'larger': 8613,
#  'projected': 11620,
#  'xwxbyhtuzc': 16322,
#  'wzedxefblg': 16217,
#  'cartoon': 2995,
#  'bears': 2116,
#  'qave': 11811,
#  'knowlddge': 8437,
#  'toilet': 14753,
#  'paper': 10972,
#  'gaabyx': 6142,
#  'purple': 11749,
#  'activist': 1129,
#  'thought': 14608,
#  'drought': 4740,
#  'buffoonmike': 2702,
#  'knew': 8422,
#  'mo': 9737,
#  'bite': 2313,
#  'influenced': 7580,
#  'shitty': 13242,
#  'staff': 13807,
#  'injuries': 7598,
#  'acquisitions': 1113,
#  'toddstarnes': 14746,
#  'enjoy': 5152,
#  'impending': 7477,
#  'landslide': 8594,
#  'todd': 14744,
#  'hehe': 6892,
#  'look': 8995,
#  'grizzly': 6550,
#  'peak': 11095,
#  'looks': 8999,
#  'beginning': 2155,
#  'dystopian': 4847,
#  'apocalypse': 1552,
#  'ignition': 7396,
#  'knock': 8430,
#  'detonation': 4339,
#  'sensor': 13092,
#  'senso': 13091,
#  'standard': 13819,
#  'ks100': 8483,
#  '7o4lnfbe7k': 815,
#  'fvzsgjtbew': 6094,
#  'week': 15858,
#  'responders': 12352,
#  'dart': 4080,
#  'members': 9475,
#  'participating': 11009,
#  'day': 4104,
#  'intensive': 7659,
#  'technical': 14395,
#  'large': 8612,
#  'animal': 1476,
#  'tl93aod3er': 14714,
#  'lot': 9033,
#  '20': 263,
#  'tom': 14761,
#  'clancy': 3346,
#  'military': 9609,
#  'mystery': 10012,
#  'novels': 10381,
#  'paperback': 10973,
#  'obix79ncxn': 10514,
#  'tomclancy': 14765,
#  'drowning': 4747,
#  'low': 9052,
#  'self': 13067,
#  'image': 7454,
#  'quiz': 11905,
#  'z8r6r3nbtb': 16543,
#  'namffldh5h': 10057,
#  'gonna': 6427,
#  'fight': 5665,
#  'taylor': 14343,
#  'soon': 13609,
#  'wish': 16012,
#  'victoria': 15551,
#  'secret': 13034,
#  'good': 6428,
#  'spot': 13738,
#  'flood': 5796,
#  'combo': 3508,
#  '53inch': 606,
#  '300w': 398,
#  'curved': 3939,
#  'cree': 3822,
#  'led': 8705,
#  'light': 8822,
#  'bar': 2004,
#  '4x4': 579,
#  'offroad': 10594,
#  'fog': 5833,
#  'lamp': 8578,
#  're': 12087,
#  'o097vsotxk': 10481,
#  'i23xy7iejj': 7293,
#  'severe': 13139,
#  'weather': 15843,
#  'bulletin': 2713,
#  'typhoon': 15116,
#  'ûï': 16685,
#  'hannaph': 6751,
#  'soudelor': 13627,
#  'tropical': 14976,
#  'warning': 15761,
#  'issued': 7780,
#  '00': 0,
#  'pm': 11353,
#  '06': 19,
#  'thhjjw51pe': 14577,
#  'fits': 5731,
#  '01': 6,
#  'bmw': 2429,
#  '325ci': 413,
#  '5l': 639,
#  'l6': 8541,
#  'gbvdnczjou': 6221,
#  'c211hise0r': 2805,
#  '10': 81,
#  'explosion': 5398,
#  'chemical': 3198,
#  'park': 10995,
#  'western': 15886,
#  'germany': 6272,
#  'xbznu0qkvs': 16247,
#  'soul': 13628,
#  'food': 5853,
#  'sound': 13632,
#  'bomb': 2459,
#  'truth': 15004,
#  'bejftygjil': 2168,
#  'news': 10192,
#  'bbc': 2077,
#  'islam': 7766,
#  'isis': 7764,
#  'terrorism': 14458,
#  'quran': 11914,
#  'lies': 8810,
#  'jlczidz7vu': 8010,
#  'if': 7380,
#  'lost': 9032,
#  'sinking': 13359,
#  'stone': 13927,
#  'carry': 2988,
#  'onå': 10701,
#  'mylittlepwnies3': 10008,
#  'early': 4883,
#  'anathemazhiv': 1446,
#  'tonysandos': 14779,
#  'lebanon': 8702,
#  '80s': 836,
#  'iran': 7735,
#  'hostage': 7137,
#  'crisis': 3845,
#  'libya': 8805,
#  'pan': 10952,
#  'pulls': 11723,
#  'gun': 6612,
#  'man': 9259,
#  'apparent': 1563,
#  'provocation': 11675,
#  'lhw4vtbhzg': 8794,
#  'dailykos': 4010,
#  'train': 14876,
#  'derailment': 4286,
#  'patna': 11039,
#  'casualty': 3016,
#  'far': 5522,
#  'indian': 7537,
#  'express': 5406,
#  'yh5vetm0yz': 16422,
#  '17wgug8z0m': 181,
#  'dream': 4698,
#  'magic': 9213,
#  'linden': 8854,
#  'method': 9523,
#  'lite': 8883,
#  'version': 15518,
#  'anxiety': 1523,
#  'panic': 10961,
#  'cure': 3929,
#  'program': 11611,
#  '073izwx0lb': 23,
#  'lind': 8852,
#  'okmlagvkjv': 10642,
#  '18': 182,
#  'bovines': 2513,
#  'rescued': 12323,
#  'smugglersåênabbed': 13516,
#  'e7fn5g5ruu': 4869,
#  'wwp': 16201,
#  'serving': 13122,
#  '75k': 777,
#  'veterans': 15524,
#  '52k': 602,
#  'oif': 10621,
#  'oef': 10558,
#  'vets': 15525,
#  'physical': 11215,
#  'invisible': 7704,
#  'ones': 10682,
#  'shhlv4dplz': 13220,
#  'client': 3375,
#  'learned': 8694,
#  'economics': 4927,
#  'south': 13642,
#  'dakota': 4014,
#  'dust': 4810,
#  'storm': 13942,
#  'years': 16396,
#  'college': 3483,
#  'hubert': 7191,
#  'humphrey': 7225,
#  'cramer': 3786,
#  'iger': 7388,
#  'words': 16090,
#  'wrecked': 16151,
#  'disney': 4495,
#  'stock': 13918,
#  'sf5jdnvdw9': 13152,
#  'til': 14671,
#  'cnbc': 3419,
#  'marc': 9286,
#  'holl': 7059,
#  'nennicook': 10163,
#  'aitchkaycee': 1292,
#  'vixstuart': 15615,
#  'benjbeckwith': 2199,
#  'pretty': 11552,
#  'disaster': 4466,
#  'gbbo': 6214,
#  'need': 10145,
#  'arcade': 1612,
#  'shooter': 13253,
#  'fix': 5735,
#  'cte': 3897,
#  'running': 12714,
#  'obliteration': 10523,
#  'buy': 2774,
#  'cod': 3448,
#  'title': 14701,
#  'weren': 15881,
#  'overpriced': 10850,
#  'steam': 13878,
#  'firepower': 5718,
#  'lab': 8553,
#  'electronic': 5023,
#  'resource': 12344,
#  'automation': 1835,
#  'infectious': 7568,
#  'diseases': 4485,
#  'bioterrorism': 2296,
#  'kvpbybglsr': 8510,
#  'graysondolan': 6512,
#  'kendall': 8287,
#  'jenner': 7954,
#  'nick': 10233,
#  'jonas': 8059,
#  'dating': 4088,
#  'literally': 8884,
#  'explode': 5390,
#  'pfvzvpxqgr': 11176,
#  'tell': 14418,
#  'mom': 9776,
#  'bring': 2615,
#  'hold': 7049,
#  'cat': 3017,
#  'rt': 12677,
#  'startelegram': 13845,
#  'homeless': 7078,
#  'vulnerable': 15680,
#  'north': 10340,
#  'texas': 14474,
#  'heat': 6877,
#  'wave': 15798,
#  'k9airfq3ql': 8189,
#  'jdbtlymehy': 7938,
#  'nuclear': 10414,
#  'solar': 13573,
#  'power': 11460,
#  'japanese': 7901,
#  'fukushima': 6061,
#  'reactor': 12096,
#  'energy': 5136,
#  'japan': 7900,
#  'temperature': 14428,
#  'fuel': 6055,
#  'pool': 11404,
#  'ys3nmwwyvc': 16497,
#  'alpotnb7q3': 1387,
#  'taken': 14282,
#  'local': 8952,
#  'wlmsq3mtho': 16039,
#  'esteemed': 5260,
#  'journalist': 8078,
#  'recalls': 12140,
#  'tragic': 14872,
#  'effects': 4973,
#  'unaddressed': 15224,
#  'childhood': 3223,
#  'trauma': 14902,
#  'keithboykin': 8276,
#  'randallpinkston': 12020,
#  'pozarmy': 11465,
#  'gxq1auzb18': 6655,
#  'feel': 5599,
#  'panicking': 10962,
#  'results': 12374,
#  'alarmingly': 1322,
#  'calm': 2871,
#  'thunder': 14642,
#  'lightning': 8828,
#  'possible': 11432,
#  'pinpoint': 11250,
#  'foothill': 5867,
#  'forecast': 5876,
#  'ctijdpxabk': 3898,
#  '40': 495,
#  'displaced': 4506,
#  'ocean': 10542,
#  'township': 14839,
#  'apartment': 1540,
#  'newyork': 10203,
#  'uelz59wvom': 15179,
#  'freddiedeboer': 5968,
#  'thucydiplease': 14640,
#  'rise': 12489,
#  'coates': 3440,
#  'charleston': 3166,
#  'massacre': 9343,
#  'walter': 15741,
#  'black': 2336,
#  'twitter': 15091,
#  'broadly': 2632,
#  'mathew': 9363,
#  'z3ke': 16535,
#  'sk1': 13395,
#  'saladinahmed': 12807,
#  'died': 4409,
#  'horrible': 7124,
#  'deaths': 4142,
#  'trapped': 14900,
#  'ships': 13234,
#  'risk': 12492,
#  'destruction': 4328,
#  'fine': 5693,
#  'reality': 12115,
#  'training': 14878,
#  'falls': 5495,
#  'elevated': 5033,
#  'tracks': 14859,
#  'windstorm': 15983,
#  'jiomnrcygt': 7999,
#  'paramedic': 10983,
#  'ems': 5102,
#  'fears': 5587,
#  'missing': 9681,
#  'migrants': 9594,
#  'med': 9435,
#  'rescuers': 12324,
#  'search': 13014,
#  'survivors': 14155,
#  'boat': 2442,
#  'carrying': 2990,
#  '6ds67xai5e': 713,
#  'derailed': 4285,
#  'benchmark': 2187,
#  'cool': 3674,
#  'paths': 11035,
#  'wonder': 16074,
#  'leaks': 8691,
#  'jobs': 8029,
#  'given': 6340,
#  'resque': 12358,
#  'new': 10181,
#  'ladies': 8563,
#  'tote': 14818,
#  'handbag': 6736,
#  'women': 16069,
#  'faux': 5552,
#  'leather': 8698,
#  'fashion': 5536,
#  'purse': 11754,
#  'y87gi3brlv': 16353,
#  '1zbhvdcxzs': 262,
#  'raishimi33': 12006,
#  'sounds': 13636,
#  'plan': 11301,
#  'little': 8889,
#  'applaud': 1569,
#  'invading': 7693,
#  'iraq': 7740,
#  'catastrophic': 3022,
#  'mistake': 9689,
#  'diplomacy': 4440,
#  'needs': 10149,
#  'replace': 12298,
#  'constant': 3635,
#  'threat': 14616,
#  'war': 15751,
#  'israel': 7777,
#  'yqjpn3quux': 16487,
#  'related': 12231,
#  'threatens': 14619,
#  'europe': 5286,
#  'wk6b5z803o': 16034,
#  'marynmck': 9335,
#  'adorable': 1173,
#  'hope': 7108,
#  'won': 16073,
#  'noticed': 10366,
#  'devastation': 4347,
#  'coming': 3520,
#  'target': 14314,
#  'starbucks': 13834,
#  'closed': 3393,
#  'momneedscoffee': 9780,
#  'asap': 1687,
#  'iwontmakeit': 7813,
#  'redskins': 12182,
#  'wr': 16142,
#  'roberts': 12544,
#  'belly': 2180,
#  'bombed': 2460,
#  'teamstream': 14386,
#  'gbcvvevdty': 6215,
#  'allah': 1359,
#  'describes': 4295,
#  'piling': 11242,
#  'wealth': 15836,
#  'thinking': 14582,
#  'forever': 5884,
#  'hellfire': 6908,
#  'surah': 14130,
#  'humaza': 7216,
#  'reflect': 12194,
#  'loved': 9042,
#  'way': 15802,
#  'book': 2474,
#  'written': 16163,
#  'include': 7514,
#  'vantage': 15464,
#  'points': 11380,
#  'detkenlang': 4336,
#  'kindle': 8370,
#  'kcrnmjkj73': 8260,
#  'heartdisease': 6870,
#  'service': 13119,
#  'spending': 13699,
#  'half': 6720,
#  'budget': 2696,
#  'kzfigkeeva': 8527,
#  'forget': 5887,
#  'tragedy': 14871,
#  'gajtugaui7': 6155,
#  'liked': 8834,
#  'youtube': 16477,
#  'itsjustinstuart': 7793,
#  'mnkaji2q1n': 9734,
#  'range': 12027,
#  'mayhem': 9385,
#  'hungerarticles': 7230,
#  'nepal': 10166,
#  'rebuilding': 12135,
#  'livelihoods': 8899,
#  'quake': 11874,
#  'lrouwjmbix': 9066,
#  'suspected': 14161,
#  'serial': 13113,
#  'arsonist': 1668,
#  'arrested': 1658,
#  'calif': 2864,
#  'pzotpdgaki': 11788,
#  'chubbysquirrel': 3283,
#  'hurricane': 7247,
#  'surge': 14138,
#  'true': 14994,
#  '33333': 416,
#  '9vw0uqqi1y': 986,
#  'marvel': 9332,
#  'vs': 15669,
#  'dc': 4110,
#  'avengers': 1846,
#  'battle': 2064,
#  'rockbottomradfm': 12553,
#  'challenges': 3133,
#  'tough': 14824,
#  'rescuing': 12325,
#  'goes': 6414,
#  'engine': 5141,
#  'tyjxrfd3st': 15111,
#  'regular': 12219,
#  'coffees': 3456,
#  'rockstar': 12561,
#  'coffee': 3455,
#  'today': 14739,
#  'tired': 14695,
#  'butt': 2769,
#  'extraordinaire': 5421,
#  'nws': 10449,
#  'wth': 16178,
#  'rotating': 12627,
#  'huge': 7201,
#  'massive': 9346,
#  'violent': 15587,
#  'tornado': 14798,
#  'j3di85ist5': 7834,
#  'swb1192': 14179,
#  'nda': 10124,
#  'damage': 4021,
#  'ability': 1045,
#  'offer': 10576,
#  'services': 13120,
#  'future': 6086,
#  'prolly': 11624,
#  'ameenshaikh3': 1416,
#  'sir': 13362,
#  'wanted': 15748,
#  'point': 11378,
#  'sureshpprabhu': 14133,
#  'said': 12796,
#  'lying': 9128,
#  'sinkhole': 13358,
#  'swallows': 14172,
#  'brooklyn': 2644,
#  'intersection': 7677,
#  'ûò': 16705,
#  '1ybe5mgzl4': 260,
#  '7zog3dpdu9': 828,
#  'jacksonville': 7862,
#  'family': 5503,
#  'bands': 1985,
#  'memorial': 9480,
#  'planned': 11306,
#  'tilgurkv7z': 14672,
#  '405': 500,
#  'southbound': 13644,
#  'coal': 3435,
#  'creek': 3823,
#  'pkwy': 11292,
#  'blocking': 2388,
#  'center': 3094,
#  'lane': 8596,
#  'im': 7449,
#  'feeling': 5601,
#  'attacked': 1771,
#  '91jvycxxvi': 908,
#  'felt': 5615,
#  'namekians': 10055,
#  'played': 11318,
#  'planet': 11304,
#  'destroyed': 4324,
#  'acc': 1075,
#  'study': 14016,
#  'conducted': 3602,
#  'skims': 13410,
#  'morethan': 9823,
#  '50': 589,
#  'population': 11413,
#  'kashmir': 8232,
#  'suffer': 14060,
#  'psychiatric': 11693,
#  'disorders': 4499,
#  'saf9mosksn': 12784,
#  'kashmirconflict': 8233,
#  'ideas': 7358,
#  'flattened': 5767,
#  'qfrawln4ba': 11828,
#  'eating': 4910,
#  'takis': 14285,
#  'rubbing': 12686,
#  'bleeding': 2366,
#  'tears': 14391,
#  'link': 8860,
#  'reddit': 12175,
#  'content': 3646,
#  'policy': 11391,
#  'effect': 4970,
#  'subreddits': 14044,
#  'banned': 1997,
#  'quarantined': 11880,
#  'cd2ng2awql': 3066,
#  'ig': 7386,
#  '2wbivkzjip': 386,
#  'hailing': 6710,
#  'abstorm': 1061,
#  'yyc': 16523,
#  'hailstorm': 6711,
#  'haildamage': 6709,
#  'yycweather': 16527,
#  'calgary': 2859,
#  'captureyyc': 2948,
#  'alberta': 1329,
#  'sto': 13916,
#  'britney': 2623,
#  'spears': 13676,
#  'vegas': 15495,
#  'missed': 9679,
#  'can': 2904,
#  'ûªt': 16683,
#  'wait': 15719,
#  'tonight': 14772,
#  'pieceofme': 11230,
#  'catastrophe': 3021,
#  '4mjyw7p7cf': 565,
#  'disco': 4472,
#  'best': 2214,
#  'song': 13596,
#  'gospel': 6454,
#  'acoustic': 1111,
#  'vcq2icptki': 15485,
#  'tune': 15040,
#  'a8jz5a26wi': 1009,
#  'theatershooting': 14518,
#  'defendant': 4190,
#  'mass': 9342,
#  'murderer': 9956,
#  'chose': 3257,
#  'testify': 14468,
#  'final': 5683,
#  'phase': 11189,
#  'subject': 14039,
#  'exam': 5327,
#  'jury': 8141,
#  'questions': 11898,
#  'brooke': 2643,
#  'face': 5457,
#  'timed': 14680,
#  'concert': 3586,
#  'screamed': 12980,
#  'minutes': 9656,
#  'straight': 13951,
#  'yup': 16510,
#  'hasn': 6799,
#  'sunk': 14098,
#  'ii2spvp89b': 7411,
#  'rodpt33xfm': 12567,
#  'eversafe': 5307,
#  'emergency': 5073,
#  'auto': 1831,
#  'kit': 8388,
#  'unsafe': 15294,
#  'hazardous': 6823,
#  'rush': 12720,
#  'hour': 7149,
#  'gridlock': 6542,
#  'jumper': 8132,
#  'ca': 2819,
#  '0bvk5tub4j': 32,
#  'demoness': 4247,
#  'voice': 15640,
#  'angel': 1464,
#  'siren': 13364,
#  'beckoning': 2133,
#  'void': 15642,
#  'this': 14588,
#  'nps3xpbkaq': 10389,
#  'aftershock': 1233,
#  'delo': 4224,
#  'speaking': 13674,
#  'scuf': 12995,
#  'xb1': 16244,
#  'end': 5121,
#  'getting': 6279,
#  'ps': 11679,
#  'anti': 1513,
#  'rear': 12123,
#  'technology': 14399,
#  'vpvj5hrc1i': 15664,
#  'techesback': 14394,
#  'tech': 14393,
#  'proud': 11667,
#  'joegoodmanjr': 8033,
#  'watching': 15788,
#  'copalibertadores': 3684,
#  'argentinean': 1627,
#  'pandemonium': 10958,
#  '8tygo0kizz': 890,
#  'causing': 3041,
#  'evacuations': 5294,
#  'downtown': 4662,
#  'hinton': 6999,
#  'mtmkimwiyy': 9923,
#  'research': 12326,
#  'collective': 3481,
#  'memory': 9482,
#  '1st': 248,
#  'rule': 12702,
#  'writing': 16160,
#  'diverse': 4527,
#  'touch': 14821,
#  'group': 6560,
#  'phfoeozyps': 11191,
#  'jax': 7920,
#  'issues': 7781,
#  'outlook': 10831,
#  'hwo': 7266,
#  'fucoqhclad': 6053,
#  'chowtaxis': 3261,
#  'newport': 10191,
#  'big': 2261,
#  'pick': 11218,
#  'jackie': 7858,
#  'bristol': 2619,
#  'temple': 14430,
#  ...}

# %%
model_TF_LR =LogisticRegression().fit(Xtf_train_matrix, y_train_list)

# %%
TF_LR_score_train =model_TF_LR.score(Xtf_train_matrix, y_train_list)

TF_LR_score_test =model_TF_LR.score(Xtf_test_matrix, y_test_list)

print('score for test data:', TF_LR_score_test)
print(classification_report(y_test_list, model_TF_LR.predict(Xtf_test_matrix)) )
# Out:
# score for test data: 0.7990367775831874
#               precision    recall  f1-score   support
#
#            0       0.80      0.88      0.83      1318
#            1       0.81      0.69      0.74       966
#
#     accuracy                           0.80      2284
#    macro avg       0.80      0.78      0.79      2284
# weighted avg       0.80      0.80      0.80      2284

# %% [markdown]
# ## Features: TFIDF,  Classifier: Randon Forest

# %%
model_TF_RF =RandomForestClassifier().fit(Xtf_train_matrix, y_train_list)

# %%
TF_RF_score_train =model_TF_RF.score(Xtf_train_matrix, y_train_list)

TF_RF_score_test =model_TF_RF.score(Xtf_test_matrix, y_test_list)

print('score for test data:', TF_RF_score_test)
print(classification_report(y_test_list, model_TF_RF.predict(Xtf_test_matrix)) )
# Out:
# score for test data: 0.7907180385288967
#               precision    recall  f1-score   support
#
#            0       0.77      0.90      0.83      1318
#            1       0.82      0.64      0.72       966
#
#     accuracy                           0.79      2284
#    macro avg       0.80      0.77      0.78      2284
# weighted avg       0.80      0.79      0.79      2284

# %%
model_TF_RF.feature_importances_
# Out:
# array([1.76307748e-04, 4.60748141e-06, 1.07280788e-07, ...,
#        3.55573785e-05, 1.03022154e-04, 3.81499096e-06])

# %%
feat_sortedlist =sorted(zip(model_TF_RF.feature_importances_, feature_names), reverse=True)

# top 10 features
feat_sortedlist[0:12]
# Out:
# [(0.02580620504542998, 'http'),
#  (0.007805966040333038, 'hiroshima'),
#  (0.0068372513135023325, 'fires'),
#  (0.006446961644316657, 'california'),
#  (0.005049010201850318, 'suicide'),
#  (0.004967358977339859, 'killed'),
#  (0.004878303955375317, 'buildings'),
#  (0.004439094565908974, 'police'),
#  (0.004420519791855518, 'wildfire'),
#  (0.004354305768179102, 'storm'),
#  (0.004051751876106769, 'train'),
#  (0.0040174188805683604, 'disaster')]

# %% [markdown]
# ## Features: TFIDF,  Classifier: XGBooster

# %%
model_TF_XGB = xgb.XGBClassifier(objective="binary:logistic", random_state=42)
model_TF_XGB.fit(Xtf_train_matrix, y_train_list)
# Out:
# XGBClassifier(base_score=0.5, booster=None, colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints=None,
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=0, num_parallel_tree=1,
#               objective='binary:logistic', random_state=42, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method=None,
#               validate_parameters=False, verbosity=None)

# %%
y_pred = model_TF_XGB.predict(Xtf_test_matrix)
#print(confusion_matrix(y_test_list, y_pred))

TF_XGB_score_train =model_TF_XGB.score(Xtf_train_matrix, y_train_list)
TF_XGB_score_test =model_TF_XGB.score(Xtf_test_matrix, y_test_list)

print('score for test data:', TF_XGB_score_test)
print(classification_report(y_test_list, model_TF_XGB.predict(Xtf_test_matrix)) )
# Out:
# score for test data: 0.7683887915936952
#               precision    recall  f1-score   support
#
#            0       0.75      0.90      0.82      1318
#            1       0.81      0.59      0.68       966
#
#     accuracy                           0.77      2284
#    macro avg       0.78      0.74      0.75      2284
# weighted avg       0.77      0.77      0.76      2284

# %% [markdown]
# ## Features: CountVectorizer,  Classifier: XGBooster

# %%
model_CV_XGB = xgb.XGBClassifier(objective="binary:logistic", random_state=42)
model_CV_XGB.fit(Xcv_train_matrix, y_train_list)
# Out:
# XGBClassifier(base_score=0.5, booster=None, colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints=None,
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=0, num_parallel_tree=1,
#               objective='binary:logistic', random_state=42, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method=None,
#               validate_parameters=False, verbosity=None)

# %%
y_pred = model_TF_XGB.predict(Xcv_test_matrix)
#print(confusion_matrix(y_test_list, y_pred))

CV_XGB_score_train =model_CV_XGB.score(Xcv_train_matrix, y_train_list)
CV_XGB_score_test =model_CV_XGB.score(Xcv_test_matrix, y_test_list)

print('score for test data:', CV_XGB_score_test)
print(classification_report(y_test_list, model_CV_XGB.predict(Xcv_test_matrix)) )
# Out:
# score for test data: 0.7850262697022767
#               precision    recall  f1-score   support
#
#            0       0.77      0.90      0.83      1318
#            1       0.83      0.62      0.71       966
#
#     accuracy                           0.79      2284
#    macro avg       0.80      0.76      0.77      2284
# weighted avg       0.79      0.79      0.78      2284

# %% [markdown]
# ## Features: CountVectorizer,  Classifier: Randon Forest

# %%
model_CV_RF =RandomForestClassifier().fit(Xcv_train_matrix, y_train_list)

# %%
CV_RF_score_train =model_CV_RF.score(Xcv_train_matrix, y_train_list)

CV_RF_score_test =model_CV_RF.score(Xcv_test_matrix, y_test_list)

print('score for test data:', CV_RF_score_test)
print(classification_report(y_test_list, model_CV_RF.predict(Xcv_test_matrix)) )
# Out:
# score for test data: 0.7784588441330998
#               precision    recall  f1-score   support
#
#            0       0.75      0.92      0.83      1318
#            1       0.84      0.59      0.69       966
#
#     accuracy                           0.78      2284
#    macro avg       0.80      0.75      0.76      2284
# weighted avg       0.79      0.78      0.77      2284
